# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import tensorflow as tf
import random
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
# Out:
# 2023-10-30 15:19:57.134121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Read dataset
train_a = pd.read_parquet('A/train_targets.parquet')
train_b = pd.read_parquet('B/train_targets.parquet')
train_c = pd.read_parquet('C/train_targets.parquet')
X_train_estimated_a = pd.read_parquet('A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('C/X_train_estimated.parquet')
X_train_observed_a = pd.read_parquet('A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('C/X_train_observed.parquet')

#add location to each sample
train_a["location"] = "A"
train_b["location"] = "B"
train_c["location"] = "C"
X_train_estimated_a["location"] = "A"
X_train_estimated_b["location"] = "B"
X_train_estimated_c["location"] = "C"
X_train_observed_a["location"] = "A"
X_train_observed_b["location"] = "B"
X_train_observed_c["location"] = "C"

#remove extra minute 00 sample
X_train_observed_a = X_train_observed_a.iloc[:-1,:]
X_train_observed_b = X_train_observed_b.iloc[:-1,:]
X_train_observed_c = X_train_observed_c.iloc[:-1,:]

#add date_calc column same as date_forecast column to observed data
X_train_observed_a.insert(0, "date_calc", X_train_observed_a["date_forecast"])
X_train_observed_b.insert(0, "date_calc", X_train_observed_b["date_forecast"])
X_train_observed_c.insert(0, "date_calc", X_train_observed_c["date_forecast"])

#concat all the samples and remove date_calc column
X_train_raw = pd.concat([X_train_observed_a,
                     X_train_observed_b,
                     X_train_observed_c,
                     X_train_estimated_a,
                     X_train_estimated_b,
                     X_train_estimated_c])

#feature indicating time between date_calc and date_forecast
X_train_raw["calc_time"] =(X_train_raw["date_forecast"] - X_train_raw["date_calc"]).astype('timedelta64[s]')

#fill nans
X_train_raw["snow_density:kgm3"] = X_train_raw["snow_density:kgm3"].apply(
    lambda a : np.isnan(a)
    ).map({True: 0, False: 1})
X_train_raw["ceiling_height_agl:m"] = X_train_raw["ceiling_height_agl:m"].apply(
    lambda a : -1000 if np.isnan(a) else a
)
X_train_raw["cloud_base_agl:m"] = X_train_raw["ceiling_height_agl:m"].apply(
    lambda a : -1000 if np.isnan(a) else a
)

#create seperate dataframes for measurments at minute 00, 15, 30 and 45
X_train00 = X_train_raw[X_train_raw["date_forecast"].apply(lambda time: time.minute == 0)].reset_index().iloc[:,1:]
X_train15 = X_train_raw[X_train_raw["date_forecast"].apply(lambda time: time.minute == 15)].reset_index().iloc[:,1:]
X_train30 = X_train_raw[X_train_raw["date_forecast"].apply(lambda time: time.minute == 30)].reset_index().iloc[:,1:]
X_train45 = X_train_raw[X_train_raw["date_forecast"].apply(lambda time: time.minute == 45)].reset_index().iloc[:,1:]

#remove redundant data
X_train15 = X_train15.iloc[:,2:-2]
X_train30 = X_train30.iloc[:,2:-2]
X_train45 = X_train45.iloc[:,2:-2]

#join observations into single sample
X_train = X_train00.join(X_train15, lsuffix="_00", rsuffix="_15").join(X_train30.join(X_train45, lsuffix="_30", rsuffix="_45"))

#rename column for merging with targets
X_train = X_train.rename(columns={"date_forecast" : "time"})

#concat target values and drop NaN values
targets = pd.concat([train_a,
                     train_b,
                     train_c]).dropna()

#merge weatherfeatures with corresponding target pv measurement
dataset = pd.merge(X_train, targets, how="right", on=["time", "location"])

#shuffle dataset
dataset = dataset.sample(frac=1, random_state=43).reset_index().iloc[:,1:]

#split into features and targets
datasetX = dataset.iloc[:, :-1]
datasetY = dataset.iloc[:, -1:]

#add day_of_year and hour feature columns
datasetX["day"] = datasetX["time"].dt.day_of_year
datasetX["hour"] = datasetX["time"].dt.hour

#get indexes of samples in the months of the test dataset
indexMayJuneJuly = datasetX["time"].apply(lambda time : time.month in [5, 6, 7])

#OHE encoding for catagorical feature "location"
#datasetX["location_A"] = datasetX["location"].apply(lambda a : a == "A").map({True: 1, False: 0})
#datasetX["location_B"] = datasetX["location"].apply(lambda a : a == "B").map({True: 1, False: 0})
#datasetX["location_C"] = datasetX["location"].apply(lambda a : a == "C").map({True: 1, False: 0})

datasetX = datasetX.drop("location", axis=1)

#move datecalc column
#date_calc_column = datasetX.pop("date_calc")
#datasetX.insert(183, "is_not_calculated", date_calc_column) #!constant 183 can be source of bugs

#fix nans for some reason???
#datasetX["is_not_calculated"] = datasetX["is_not_calculated"].fillna(method="ffill")

#map location labels to numbers
#datasetX["location"] = datasetX["location"].map({"A": 0, "B": 1, "C": 2})

#drop time and date_calc columns
datasetX = datasetX.iloc[:,2:]

#calculate mean and std for normalizing data, values should also be used for normalizing test data
dataMean = datasetX.mean()
dataStd = datasetX.std()

#normalize data
datasetX.iloc[:,:-1] = ((datasetX.iloc[:,:-1]-dataMean[:-1])/dataStd[:-1]).fillna(value=0)


#partition into training and evalset
trainsetX = datasetX.iloc[:85000,:]
trainsetY = datasetY.iloc[:85000,:]
trainsetIndexMayJuneJuly = indexMayJuneJuly[:85000]
evalsetX = datasetX.iloc[85000:,:]
evalsetY = datasetY.iloc[85000:,:]
evalsetIndexMayJuneJuly = indexMayJuneJuly[85000:]

display(datasetX)
# Out:
# /var/folders/bm/37km6rb530l8y0vv0znc0zb00000gn/T/ipykernel_28002/216928764.py:119: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized.
#   datasetX.iloc[:,:-1] = ((datasetX.iloc[:,:-1]-dataMean[:-1])/dataStd[:-1]).fillna(value=0)
#        absolute_humidity_2m:gm3_00  air_density_2m:kgm3_00  \
# 0                         1.761765               -0.585518
# 1                         2.056473               -1.514269
# 2                        -1.737899                3.539239
# 3                         0.693446               -1.049894
# 4                        -0.043325               -0.039193
# ...                            ...                     ...
# 93019                     1.761765               -0.940630
# 93020                     1.430217               -1.077211
# 93021                    -0.780097                1.381254
# 93022                     0.435576                0.261286
# 93023                    -1.074805                0.343236
#
#        ceiling_height_agl:m_00  clear_sky_energy_1h:J_00  clear_sky_rad:W_00  \
# 0                    -0.372920                 -0.627834           -0.626244
# 1                    -1.083697                 -0.511048           -0.405245
# 2                    -0.412686                 -0.626565           -0.610052
# 3                    -1.083697                  0.532847            0.340902
# 4                    -0.325236                 -0.627834           -0.626244
# ...                        ...                       ...                 ...
# 93019                -0.343415                 -0.609817           -0.541345
# 93020                -0.203188                 -0.353779           -0.143984
# 93021                -1.083697                 -0.627834           -0.626244
# 93022                -1.083697                 -0.627834           -0.626244
# 93023                -0.125634                 -0.570831           -0.519902
#
#        cloud_base_agl:m_00  dew_or_rime:idx_00  dew_point_2m:K_00  \
# 0                -0.372920           -0.028554           1.486874
# 1                -1.083697           -0.028554           1.691712
# 2                -0.412686           -0.028554          -2.653814
# 3                -1.083697           -0.028554           0.828460
# 4                -0.325236           -0.028554           0.140786
# ...                    ...                 ...                ...
# 93019            -0.343415           -0.028554           1.486874
# 93020            -0.203188           -0.028554           1.296667
# 93021            -1.083697           -0.028554          -0.722471
# 93022            -1.083697           -0.028554           0.565096
# 93023            -0.125634           -0.028554          -1.161413
#
#        diffuse_rad:W_00  diffuse_rad_1h:J_00  direct_rad:W_00  \
# 0             -0.651235            -0.658524        -0.444504
# 1             -0.204391            -0.371468        -0.170922
# 2             -0.590227            -0.627996        -0.444504
# 3              0.224316             0.276981         1.045587
# 4             -0.651235            -0.658524        -0.444504
# ...                 ...                  ...              ...
# 93019         -0.585281            -0.625446        -0.444504
# 93020         -0.326408            -0.456205        -0.443619
# 93021         -0.651235            -0.658524        -0.444504
# 93022         -0.651235            -0.658524        -0.444504
# 93023         -0.474806            -0.565454        -0.444504
#
#        direct_rad_1h:J_00  effective_cloud_cover:p_00  elevation:m_00  \
# 0               -0.449899                    0.941265       -0.685740
# 1               -0.311598                   -1.900810        1.599325
# 2               -0.449899                   -0.359926       -0.685740
# 3                1.355175                   -1.889396        1.599325
# 4               -0.449899                    0.941265       -0.558792
# ...                   ...                         ...             ...
# 93019           -0.449899                    0.941265       -0.558792
# 93020           -0.449516                    0.941265        1.599325
# 93021           -0.449899                   -1.912224       -0.558792
# 93022           -0.449899                   -0.474065       -0.685740
# 93023           -0.449899                    0.941265       -0.685740
#
#        fresh_snow_12h:cm_00  fresh_snow_1h:cm_00  fresh_snow_24h:cm_00  \
# 0                 -0.148871            -0.085506             -0.188709
# 1                 -0.148871            -0.085506             -0.188709
# 2                 -0.148871            -0.085506             -0.188709
# 3                 -0.148871            -0.085506             -0.188709
# 4                 -0.148871            -0.085506             -0.188709
# ...                     ...                  ...                   ...
# 93019             -0.148871            -0.085506             -0.188709
# 93020             -0.148871            -0.085506             -0.188709
# 93021             -0.148871            -0.085506             -0.188709
# 93022             -0.148871            -0.085506             -0.188709
# 93023              4.592443             3.466229              2.848436
#
#        fresh_snow_3h:cm_00  fresh_snow_6h:cm_00  is_day:idx_00  \
# 0                -0.103329            -0.120629      -0.967213
# 1                -0.103329            -0.120629       1.033887
# 2                -0.103329            -0.120629       1.033887
# 3                -0.103329            -0.120629       1.033887
# 4                -0.103329            -0.120629      -0.967213
# ...                    ...                  ...            ...
# 93019            -0.103329            -0.120629       1.033887
# 93020            -0.103329            -0.120629       1.033887
# 93021            -0.103329            -0.120629      -0.967213
# 93022            -0.103329            -0.120629      -0.967213
# 93023             4.172156             5.072674       1.033887
#
#        is_in_shadow:idx_00  msl_pressure:hPa_00  precip_5min:mm_00  \
# 0                 0.876756             0.901320          -0.169307
# 1                -1.140556             0.175523          -0.169307
# 2                 0.876756             1.695875          -0.169307
# 3                -1.140556             0.565164          -0.169307
# 4                 0.876756            -0.290514           1.919558
# ...                    ...                  ...                ...
# 93019            -1.140556            -0.122434          -0.169307
# 93020            -1.140556            -0.626675          -0.169307
# 93021             0.876756             1.329162          -0.169307
# 93022             0.876756             1.061763          -0.169307
# 93023            -1.140556            -1.474710          -0.169307
#
#        precip_type_5min:idx_00  pressure_100m:hPa_00  pressure_50m:hPa_00  \
# 0                    -0.216311              0.974825             0.968096
# 1                    -0.216311              0.075401             0.057415
# 2                    -0.216311              1.682065             1.725726
# 3                    -0.216311              0.444394             0.432399
# 4                     2.381738             -0.239780            -0.241047
# ...                        ...                   ...                  ...
# 93019                -0.216311             -0.039910            -0.049726
# 93020                -0.216311             -0.739460            -0.746130
# 93021                -0.216311              1.359194             1.373698
# 93022                -0.216311              1.136258             1.136459
# 93023                -0.216311             -1.439014            -1.427232
#
#        prob_rime:p_00  rain_water:kgm2_00  relative_humidity_1000hPa:p_00  \
# 0           -0.139261           -0.225220                        1.160650
# 1           -0.139261           -0.225220                       -0.444536
# 2           -0.139261           -0.225220                        0.295245
# 3           -0.139261           -0.225220                       -1.079632
# 4           -0.139261           -0.225220                        0.672115
# ...               ...                 ...                             ...
# 93019       -0.139261            9.084127                        1.488666
# 93020       -0.139261            4.429454                        1.349085
# 93021       -0.139261           -0.225220                       -1.044737
# 93022       -0.139261           -0.225220                        0.448785
# 93023       -0.139261           -0.225220                       -0.130478
#
#        sfc_pressure:hPa_00  snow_density:kgm3_00  snow_depth:cm_00  \
# 0                 0.959170             -0.216887         -0.154033
# 1                 0.037486             -0.216887         -0.154033
# 2                 1.758972             -0.216887         -0.154033
# 3                 0.418346             -0.216887         -0.154033
# 4                -0.236731             -0.216887         -0.154033
# ...                    ...                   ...               ...
# 93019            -0.061536             -0.216887         -0.154033
# 93020            -0.754700             -0.216887         -0.154033
# 93021             1.385737             -0.216887         -0.154033
# 93022             1.134365             -0.216887         -0.154033
# 93023            -1.417397             -0.216887         -0.154033
#
#        snow_drift:idx_00  snow_melt_10min:mm_00  snow_water:kgm2_00  \
# 0              -0.004639              -0.063716           -0.359869
# 1              -0.004639              -0.063716           -0.359869
# 2              -0.004639              -0.063716           -0.359869
# 3              -0.004639              -0.063716           -0.359869
# 4              -0.004639              -0.063716            2.827492
# ...                  ...                    ...                 ...
# 93019          -0.004639              -0.063716            0.835392
# 93020          -0.004639              -0.063716            3.624333
# 93021          -0.004639              -0.063716           -0.359869
# 93022          -0.004639              -0.063716           -0.359869
# 93023          -0.004639              -0.063716            1.632232
#
#        sun_azimuth:d_00  sun_elevation:d_00  \
# 0              1.672429           -0.411879
# 1             -1.304262            0.291272
# 2             -0.359130            0.071243
# 3              0.418522            0.694970
# 4             -0.914508           -0.569227
# ...                 ...                 ...
# 93019         -0.960897            0.162703
# 93020         -1.014514            0.455117
# 93021          1.228697           -0.876343
# 93022          1.529396           -0.677972
# 93023         -0.222850            0.181861
#
#        super_cooled_liquid_water:kgm2_00  t_1000hPa:K_00  \
# 0                               0.386216        0.915437
# 1                              -0.510793        1.989000
# 2                              -0.510793       -2.366598
# 3                              -0.510793        1.176162
# 4                               1.283226       -0.127451
# ...                                  ...             ...
# 93019                           1.283226        1.176162
# 93020                           0.386216        0.869429
# 93021                          -0.510793       -0.740916
# 93022                          -0.510793        0.255964
# 93023                           0.386216       -1.185677
#
#        total_cloud_cover:p_00  visibility:m_00  wind_speed_10m:ms_00  \
# 0                    0.754314        -0.758072             -0.920948
# 1                   -2.080535         0.781241             -1.089629
# 2                   -0.345905        -0.366078             -0.920948
# 3                   -2.080535         1.168928              1.046996
# 4                    0.754314        -1.692673              1.328131
# ...                       ...              ...                   ...
# 93019                0.754314        -1.758058             -1.089629
# 93020                0.754314        -1.754434              0.316045
# 93021               -2.103397         0.754520             -0.696040
# 93022               -0.663110        -0.922474             -0.920948
# 93023                0.754314        -0.520943              1.328131
#
#        wind_speed_u_10m:ms_00  wind_speed_v_10m:ms_00  \
# 0                    0.262526               -0.254297
# 1                   -0.413872                0.167422
# 2                   -0.164673                0.378282
# 3                   -1.695469                1.116291
# 4                    1.686523               -0.096152
# ...                       ...                     ...
# 93019                0.120127               -0.043437
# 93020                1.045724               -0.676017
# 93021               -0.805471                0.009278
# 93022                0.226926               -0.201582
# 93023               -0.093473               -3.206334
#
#        wind_speed_w_1000hPa:ms_00  calc_time  absolute_humidity_2m:gm3_15  \
# 0                        0.002482  -0.352674                     1.763181
# 1                        0.002482  -0.352674                     2.131845
# 2                        0.002482  -0.352674                    -1.739131
# 3                        0.002482  -0.352674                     0.694054
# 4                        0.002482  -0.352674                    -0.043275
# ...                           ...        ...                          ...
# 93019                    0.002482  -0.352674                     1.800047
# 93020                    0.002482  -0.352674                     1.468250
# 93021                    0.002482  -0.352674                    -0.780603
# 93022                    0.002482  -0.352674                     0.435989
# 93023                    0.002482  -0.352674                    -1.075535
#
#        air_density_2m:kgm3_15  ceiling_height_agl:m_15  \
# 0                   -0.585998                -0.478451
# 1                   -1.570235                -1.164946
# 2                    3.514983                -0.514123
# 3                   -1.023434                -1.164946
# 4                   -0.011860                -0.437688
# ...                       ...                      ...
# 93019               -0.941417                -0.382380
# 93020               -1.078116                -0.256492
# 93021                1.409815                -1.164946
# 93022                0.261538                -1.164946
# 93023                0.343559                -0.200421
#
#        clear_sky_energy_1h:J_15  clear_sky_rad:W_15  cloud_base_agl:m_15  \
# 0                     -0.627839           -0.626183            -0.478451
# 1                     -0.460303           -0.329046            -1.164946
# 2                     -0.618464           -0.580234            -0.514123
# 3                      0.438664            0.235035            -1.164946
# 4                     -0.627839           -0.626183            -0.437688
# ...                         ...                 ...                  ...
# 93019                 -0.581357           -0.473895            -0.382380
# 93020                 -0.252382           -0.017904            -0.256492
# 93021                 -0.627839           -0.626183            -1.164946
# 93022                 -0.627839           -0.626183            -1.164946
# 93023                 -0.545598           -0.497526            -0.200421
#
#        dew_or_rime:idx_15  dew_point_2m:K_15  diffuse_rad:W_15  \
# 0               -0.028313           1.502325         -0.648966
# 1               -0.028313           1.721921         -0.123742
# 2               -0.028313          -2.626084         -0.502430
# 3               -0.028313           0.828896          0.175916
# 4               -0.028313           0.126190         -0.648966
# ...                   ...                ...               ...
# 93019           -0.028313           1.502325         -0.517248
# 93020           -0.028313           1.297369         -0.232409
# 93021           -0.028313          -0.722918         -0.648966
# 93022           -0.028313           0.565382         -0.648966
# 93023           -0.028313          -1.162110         -0.459622
#
#        diffuse_rad_1h:J_15  direct_rad:W_15  direct_rad_1h:J_15  \
# 0                -0.656967        -0.443498           -0.449477
# 1                -0.290890        -0.056782           -0.253685
# 2                -0.582871        -0.443498           -0.449477
# 3                 0.244133         0.879991            1.201048
# 4                -0.656967        -0.443498           -0.449477
# ...                    ...              ...                 ...
# 93019            -0.590134        -0.443498           -0.449477
# 93020            -0.386458        -0.442616           -0.448953
# 93021            -0.656967        -0.443498           -0.449477
# 93022            -0.656967        -0.443498           -0.449477
# 93023            -0.520602        -0.443498           -0.449477
#
#        effective_cloud_cover:p_15  elevation:m_15  fresh_snow_12h:cm_15  \
# 0                        0.955439       -0.685740              -0.15017
# 1                       -1.928510        1.599325              -0.15017
# 2                       -0.171421       -0.685740              -0.15017
# 3                       -1.841382        1.599325              -0.15017
# 4                        0.955439       -0.558792              -0.15017
# ...                           ...             ...                   ...
# 93019                    0.955439       -0.558792              -0.15017
# 93020                    0.955439        1.599325              -0.15017
# 93021                   -1.832669       -0.558792              -0.15017
# 93022                   -0.493796       -0.685740              -0.15017
# 93023                    0.955439       -0.685740               5.33806
#
#        fresh_snow_1h:cm_15  fresh_snow_24h:cm_15  fresh_snow_3h:cm_15  \
# 0                -0.087599             -0.189691            -0.104406
# 1                -0.087599             -0.189691            -0.104406
# 2                -0.087599             -0.189691            -0.104406
# 3                -0.087599             -0.189691            -0.104406
# 4                -0.087599             -0.189691            -0.104406
# ...                    ...                   ...                  ...
# 93019            -0.087599             -0.189691            -0.104406
# 93020            -0.087599             -0.189691            -0.104406
# 93021            -0.087599             -0.189691            -0.104406
# 93022            -0.087599             -0.189691            -0.104406
# 93023             4.392178              3.315914             4.516852
#
#        fresh_snow_6h:cm_15  is_day:idx_15  is_in_shadow:idx_15  \
# 0                -0.121976      -0.967713             0.879292
# 1                -0.121976       1.033353            -1.137266
# 2                -0.121976       1.033353             0.879292
# 3                -0.121976       1.033353            -1.137266
# 4                -0.121976      -0.967713             0.879292
# ...                    ...            ...                  ...
# 93019            -0.121976       1.033353            -1.137266
# 93020            -0.121976       1.033353            -1.137266
# 93021            -0.121976      -0.967713             0.879292
# 93022            -0.121976      -0.967713             0.879292
# 93023             5.065787       1.033353            -1.137266
#
#        msl_pressure:hPa_15  precip_5min:mm_15  precip_type_5min:idx_15  \
# 0                 0.909142          -0.167672                -0.217955
# 1                 0.175557          -0.167672                -0.217955
# 2                 1.696210          -0.167672                -0.217955
# 3                 0.565276          -0.167672                -0.217955
# 4                -0.290571          -0.167672                -0.217955
# ...                    ...                ...                      ...
# 93019            -0.114818          -0.167672                -0.217955
# 93020            -0.626798          -0.167672                -0.217955
# 93021             1.329424          -0.167672                -0.217955
# 93022             1.061972          -0.167672                -0.217955
# 93023            -1.475001          -0.167672                -0.217955
#
#        pressure_100m:hPa_15  pressure_50m:hPa_15  prob_rime:p_15  \
# 0                  0.982738             0.975945       -0.138798
# 1                  0.075444             0.057439       -0.138798
# 2                  1.682434             1.726056       -0.138798
# 3                  0.444512             0.432493       -0.138798
# 4                 -0.239801            -0.241077       -0.138798
# ...                     ...                  ...             ...
# 93019             -0.032198            -0.042065       -0.138798
# 93020             -0.731894            -0.746253       -0.138798
# 93021              1.359497             1.373965       -0.138798
# 93022              1.136516             1.129029       -0.138798
# 93023             -1.431586            -1.427480       -0.138798
#
#        rain_water:kgm2_15  relative_humidity_1000hPa:p_15  \
# 0               -0.226485                        1.174085
# 1               -0.226485                       -0.440042
# 2               -0.226485                        0.254735
# 3               -0.226485                       -1.057621
# 4               -0.226485                        0.710901
# ...                   ...                             ...
# 93019            9.297173                        1.496911
# 93020            4.535344                        1.314444
# 93021           -0.226485                       -1.008496
# 93022           -0.226485                        0.458255
# 93023           -0.226485                       -0.138271
#
#        sfc_pressure:hPa_15  snow_density:kgm3_15  snow_depth:cm_15  \
# 0                 0.959360             -0.216288         -0.153997
# 1                 0.037494             -0.216288         -0.153997
# 2                 1.759319             -0.216288         -0.153997
# 3                 0.418429             -0.216288         -0.153997
# 4                -0.236778             -0.216288         -0.153997
# ...                    ...                   ...               ...
# 93019            -0.053927             -0.216288         -0.153997
# 93020            -0.754849             -0.216288         -0.153997
# 93021             1.386010             -0.216288         -0.153997
# 93022             1.126972             -0.216288         -0.153997
# 93023            -1.417677             -0.216288         -0.153997
#
#        snow_drift:idx_15  snow_melt_10min:mm_15  snow_water:kgm2_15  \
# 0              -0.004639              -0.063299           -0.374748
# 1              -0.004639              -0.063299           -0.374748
# 2              -0.004639              -0.063299           -0.374748
# 3              -0.004639              -0.063299           -0.374748
# 4              -0.004639              -0.063299            2.531443
# ...                  ...                    ...                 ...
# 93019          -0.004639              -0.063299            1.285933
# 93020          -0.004639              -0.063299            4.192123
# 93021          -0.004639              -0.063299           -0.374748
# 93022          -0.004639              -0.063299           -0.374748
# 93023          -0.004639              -0.063299            1.701103
#
#        sun_azimuth:d_15  sun_elevation:d_15  \
# 0              1.722533           -0.416355
# 1             -1.255956            0.344827
# 2             -0.310215            0.109259
# 3              0.469444            0.643452
# 4             -0.865340           -0.499237
# ...                 ...                 ...
# 93019         -0.911775            0.232457
# 93020         -0.965822            0.524085
# 93021          1.280481           -0.929432
# 93022          1.581383           -0.699945
# 93023         -0.173366            0.204427
#
#        super_cooled_liquid_water:kgm2_15  t_1000hPa:K_15  \
# 0                               0.397222        0.916001
# 1                              -0.527242        2.005538
# 2                              -0.527242       -2.352607
# 3                              -0.527242        1.161531
# 4                               1.321686       -0.158190
# ...                                  ...             ...
# 93019                           1.321686        1.176877
# 93020                           0.397222        0.869966
# 93021                          -0.527242       -0.756667
# 93022                          -0.527242        0.256142
# 93023                           0.397222       -1.201688
#
#        total_cloud_cover:p_15  visibility:m_15  wind_speed_10m:ms_15  \
# 0                    0.768194        -0.882030             -0.928493
# 1                   -2.113165         0.802297             -1.098538
# 2                   -0.161088        -0.377002             -0.928493
# 3                   -1.967052         1.166093              0.998685
# 4                    0.768194        -1.713519              1.225412
# ...                       ...              ...                   ...
# 93019                0.768194        -1.788747             -1.041856
# 93020                0.768194        -1.785929              0.261823
# 93021               -1.920295         0.742945             -0.758448
# 93022               -0.690019        -0.856602             -0.985174
# 93023                0.768194        -0.582670              1.338775
#
#        wind_speed_u_10m:ms_15  wind_speed_v_10m:ms_15  \
# 0                    0.262052               -0.310718
# 1                   -0.414939                0.166633
# 2                   -0.165521                0.378790
# 3                   -1.662027                1.068298
# 4                    1.580402                0.007516
# ...                       ...                     ...
# 93019                0.119528                0.007516
# 93020                1.010305               -0.681992
# 93021               -0.806881               -0.045523
# 93022                0.226421               -0.151601
# 93023               -0.165521               -3.227868
#
#        wind_speed_w_1000hPa:ms_15  absolute_humidity_2m:gm3_30  \
# 0                        0.002208                     1.800498
# 1                        0.002208                     2.169249
# 2                        0.002208                    -1.739516
# 3                        0.002208                     0.694243
# 4                        0.002208                    -0.080135
# ...                           ...                          ...
# 93019                    0.002208                     1.800498
# 93020                    0.002208                     1.468622
# 93021                    0.002208                    -0.780762
# 93022                    0.002208                     0.436117
# 93023                    0.002208                    -1.075764
#
#        air_density_2m:kgm3_30  ceiling_height_agl:m_30  \
# 0                   -0.586261                -0.498677
# 1                   -1.625503                -1.170749
# 2                    3.488663                -0.530736
# 3                   -0.996488                -1.170749
# 4                    0.015408                -0.464787
# ...                       ...                      ...
# 93019               -0.969138                -0.334757
# 93020               -1.105880                -0.221342
# 93021                1.437526                -1.170749
# 93022                0.288892                -1.170749
# 93023                0.343588                -0.185916
#
#        clear_sky_energy_1h:J_30  clear_sky_rad:W_30  cloud_base_agl:m_30  \
# 0                     -0.627835           -0.626218            -0.498677
# 1                     -0.397429           -0.240677            -1.170749
# 2                     -0.603627           -0.553136            -0.530736
# 3                      0.338281            0.124735            -1.170749
# 4                     -0.627835           -0.626218            -0.464787
# ...                         ...                 ...                  ...
# 93019                 -0.531996           -0.385528            -0.334757
# 93020                 -0.137770            0.115982            -0.221342
# 93021                 -0.627835           -0.626218            -1.170749
# 93022                 -0.627835           -0.626218            -1.170749
# 93023                 -0.522020           -0.477428            -0.185916
#
#        dew_or_rime:idx_30  dew_point_2m:K_30  diffuse_rad:W_30  \
# 0               -0.027486           1.502605         -0.643902
# 1               -0.027486           1.751531         -0.058169
# 2               -0.027486          -2.611955         -0.448658
# 3               -0.027486           0.814403          0.114105
# 4               -0.027486           0.111562         -0.643902
# ...                   ...                ...               ...
# 93019           -0.027486           1.517249         -0.412562
# 93020           -0.027486           1.312254         -0.130360
# 93021           -0.027486          -0.737705         -0.643902
# 93022           -0.027486           0.565482         -0.643902
# 93023           -0.027486          -1.176982         -0.455221
#
#        diffuse_rad_1h:J_30  direct_rad:W_30  direct_rad_1h:J_30  \
# 0                -0.653964        -0.440573           -0.448215
# 1                -0.217717         0.083043           -0.121473
# 2                -0.554471        -0.440573           -0.448215
# 3                 0.199186         0.703851            1.035289
# 4                -0.653964        -0.440573           -0.448215
# ...                    ...              ...                 ...
# 93019            -0.536554        -0.440573           -0.448215
# 93020            -0.306574        -0.439698           -0.447596
# 93021            -0.653964        -0.440573           -0.448215
# 93022            -0.653964        -0.440573           -0.448215
# 93023            -0.497880        -0.440573           -0.448215
#
#        effective_cloud_cover:p_30  elevation:m_30  fresh_snow_12h:cm_30  \
# 0                        0.960342       -0.685740             -0.149072
# 1                       -1.932135        1.599325             -0.149072
# 2                        0.016634       -0.685740             -0.149072
# 3                       -1.768520        1.599325             -0.149072
# 4                        0.960342       -0.558792             -0.149072
# ...                           ...             ...                   ...
# 93019                    0.960342       -0.558792             -0.149072
# 93020                    0.960342        1.599325             -0.149072
# 93021                   -1.727616       -0.558792             -0.149072
# 93022                   -0.506349       -0.685740             -0.149072
# 93023                    0.960342       -0.685740              5.328155
#
#        fresh_snow_1h:cm_30  fresh_snow_24h:cm_30  fresh_snow_3h:cm_30  \
# 0                -0.087486             -0.188034            -0.104584
# 1                -0.087486             -0.188034            -0.104584
# 2                -0.087486             -0.188034            -0.104584
# 3                -0.087486             -0.188034            -0.104584
# 4                -0.087486             -0.188034            -0.104584
# ...                    ...                   ...                  ...
# 93019            -0.087486             -0.188034            -0.104584
# 93020            -0.087486             -0.188034            -0.104584
# 93021            -0.087486             -0.188034            -0.104584
# 93022            -0.087486             -0.188034            -0.104584
# 93023             4.406288              3.306565             4.544983
#
#        fresh_snow_6h:cm_30  is_day:idx_30  is_in_shadow:idx_30  \
# 0                -0.121631      -0.966276             0.879543
# 1                -0.121631       1.034890            -1.136943
# 2                -0.121631       1.034890             0.879543
# 3                -0.121631       1.034890            -1.136943
# 4                -0.121631      -0.966276             0.879543
# ...                    ...            ...                  ...
# 93019            -0.121631       1.034890            -1.136943
# 93020            -0.121631       1.034890            -1.136943
# 93021            -0.121631      -0.966276             0.879543
# 93022            -0.121631      -0.966276             0.879543
# 93023             5.073072       1.034890            -1.136943
#
#        msl_pressure:hPa_30  precip_5min:mm_30  precip_type_5min:idx_30  \
# 0                 0.916878          -0.172386                 -0.21722
# 1                 0.175587          -0.172386                 -0.21722
# 2                 1.696376          -0.172386                 -0.21722
# 3                 0.565341          -0.172386                 -0.21722
# 4                -0.282943          -0.172386                 -0.21722
# ...                    ...                ...                      ...
# 93019            -0.107174          -0.172386                 -0.21722
# 93020            -0.619196          -0.172386                 -0.21722
# 93021             1.329558          -0.172386                 -0.21722
# 93022             1.062082          -0.172386                 -0.21722
# 93023            -1.467479          -0.172386                 -0.21722
#
#        pressure_100m:hPa_30  pressure_50m:hPa_30  prob_rime:p_30  \
# 0                  0.990524             0.983688       -0.139012
# 1                  0.075464             0.057449       -0.139012
# 2                  1.682585             1.718560       -0.139012
# 3                  0.444562             0.432535       -0.139012
# 4                 -0.239806            -0.233436       -0.139012
# ...                     ...                  ...             ...
# 93019             -0.024499            -0.042064       -0.139012
# 93020             -0.731940            -0.746314       -0.139012
# 93021              1.359622             1.374090       -0.139012
# 93022              1.128935             1.129133       -0.139012
# 93023             -1.431688            -1.419942       -0.139012
#
#        rain_water:kgm2_30  relative_humidity_1000hPa:p_30  \
# 0               -0.226715                        1.190330
# 1               -0.226715                       -0.426862
# 2               -0.226715                        0.212983
# 3               -0.226715                       -1.031552
# 4               -0.226715                        0.754391
# ...                   ...                             ...
# 93019            9.336886                        1.492675
# 93020            4.555086                        1.267674
# 93021           -0.226715                       -0.975302
# 93022           -0.226715                        0.473140
# 93023           -0.226715                       -0.138580
#
#        sfc_pressure:hPa_30  snow_density:kgm3_30  snow_depth:cm_30  \
# 0                 0.967062             -0.216506         -0.154018
# 1                 0.037510             -0.216506         -0.154018
# 2                 1.759463             -0.216506         -0.154018
# 3                 0.418474             -0.216506         -0.154018
# 4                -0.236781             -0.216506         -0.154018
# ...                    ...                   ...               ...
# 93019            -0.053917             -0.216506         -0.154018
# 93020            -0.754891             -0.216506         -0.154018
# 93021             1.386126             -0.216506         -0.154018
# 93022             1.127069             -0.216506         -0.154018
# 93023            -1.410150             -0.216506         -0.154018
#
#        snow_drift:idx_30  snow_melt_10min:mm_30  snow_water:kgm2_30  \
# 0              -0.004639               -0.06382           -0.380472
# 1              -0.004639               -0.06382           -0.380472
# 2              -0.004639               -0.06382           -0.380472
# 3              -0.004639               -0.06382           -0.380472
# 4              -0.004639               -0.06382            2.146367
# ...                  ...                    ...                 ...
# 93019          -0.004639               -0.06382            1.304088
# 93020          -0.004639               -0.06382            4.252066
# 93021          -0.004639               -0.06382           -0.380472
# 93022          -0.004639               -0.06382           -0.380472
# 93023          -0.004639               -0.06382            2.146367
#
#        sun_azimuth:d_30  sun_elevation:d_30  \
# 0             -1.695778           -0.416310
# 1             -1.183205            0.400794
# 2             -0.234472            0.143726
# 3              0.548195            0.589013
# 4             -0.790943           -0.429388
# ...                 ...                 ...
# 93019         -0.837271            0.302415
# 93020         -0.891794            0.593678
# 93021          1.362902           -0.979344
# 93022          1.664258           -0.717403
# 93023         -0.096820            0.222945
#
#        super_cooled_liquid_water:kgm2_30  t_1000hPa:K_30  \
# 0                               0.406303        0.916208
# 1                              -0.532899        2.005926
# 2                              -0.532899       -2.337592
# 3                              -0.532899        1.161779
# 4                               0.406303       -0.188854
# ...                                  ...             ...
# 93019                           2.284706        1.161779
# 93020                           0.406303        0.885515
# 93021                          -0.532899       -0.772085
# 93022                          -0.532899        0.256241
# 93023                           0.406303       -1.201831
#
#        total_cloud_cover:p_30  visibility:m_30  wind_speed_10m:ms_30  \
# 0                    0.773033        -0.998379             -0.931325
# 1                   -2.115496         0.814409             -1.101869
# 2                    0.016303        -0.384539             -0.874476
# 3                   -1.818104         1.149019              0.944668
# 4                    0.773033        -1.714306              1.058365
# ...                       ...              ...                   ...
# 93019                0.773033        -1.798701             -0.988173
# 93020                0.773033        -1.796716              0.205641
# 93021               -1.697381         0.722216             -0.760780
# 93022               -0.705093        -0.778912             -0.988173
# 93023                0.773033        -0.638701              1.285758
#
#        wind_speed_u_10m:ms_30  wind_speed_v_10m:ms_30  \
# 0                    0.261668               -0.365118
# 1                   -0.451140                0.166468
# 2                   -0.130376                0.432261
# 3                   -1.662915                0.963846
# 4                    1.473443                0.166468
# ...                       ...                     ...
# 93019                0.154747                0.060151
# 93020                0.938837               -0.684069
# 93021               -0.807544               -0.046167
# 93022                0.190388               -0.152484
# 93023               -0.201657               -3.182522
#
#        wind_speed_w_1000hPa:ms_30  absolute_humidity_2m:gm3_45  \
# 0                        0.000171                     1.800118
# 1                        0.000171                     2.242523
# 2                        0.000171                    -1.739117
# 3                        0.000171                     0.694107
# 4                        0.000171                    -0.080100
# ...                           ...                          ...
# 93019                    0.000171                     1.836986
# 93020                    0.000171                     1.468315
# 93021                    0.000171                    -0.780574
# 93022                    0.000171                     0.436038
# 93023                    0.000171                    -1.075511
#
#        air_density_2m:kgm3_45  ceiling_height_agl:m_45  \
# 0                   -0.586040                -0.514379
# 1                   -1.652262                -1.165899
# 2                    3.460144                -0.542557
# 3                   -0.968785                -1.165899
# 4                    0.042759                -0.488245
# ...                       ...                      ...
# 93019               -0.968785                -0.283846
# 93020               -1.105481                -0.183983
# 93021                1.464393                -1.165899
# 93022                0.288812                -1.165899
# 93023                0.343490                -0.169639
#
#        clear_sky_energy_1h:J_45  clear_sky_rad:W_45  cloud_base_agl:m_45  \
# 0                     -0.627838           -0.626252            -0.514379
# 1                     -0.321742           -0.140925            -1.165899
# 2                     -0.582067           -0.526473            -0.542557
# 3                      0.232786            0.012243            -1.165899
# 4                     -0.627838           -0.626252            -0.488245
# ...                         ...                 ...                  ...
# 93019                 -0.461926           -0.280090            -0.283846
# 93020                 -0.012910            0.254687            -0.183983
# 93021                 -0.627838           -0.626252            -1.165899
# 93022                 -0.627838           -0.626252            -1.165899
# 93023                 -0.500232           -0.460829            -0.169639
#
#        dew_or_rime:idx_45  dew_point_2m:K_45  diffuse_rad:W_45  \
# 0               -0.026713           1.516948         -0.649161
# 1               -0.026713           1.780455          0.027596
# 2               -0.026713          -2.582084         -0.374177
# 3               -0.026713           0.814254          0.093460
# 4               -0.026713           0.096924         -0.649161
# ...                   ...                ...               ...
# 93019           -0.026713           1.516948         -0.361004
# 93020           -0.026713           1.311997         -0.036622
# 93021           -0.026713          -0.752159         -0.649161
# 93022           -0.026713           0.550747         -0.649161
# 93023           -0.026713          -1.176701         -0.431808
#
#        diffuse_rad_1h:J_45  direct_rad:W_45  direct_rad_1h:J_45  \
# 0                -0.657170        -0.443468           -0.449428
# 1                -0.133635         0.232834           -0.013126
# 2                -0.517699        -0.379016           -0.416816
# 3                 0.178291         0.515362            0.868124
# 4                -0.657170        -0.443468           -0.449428
# ...                    ...              ...                 ...
# 93019            -0.500630        -0.442585           -0.448915
# 93020            -0.224810        -0.440819           -0.447892
# 93021            -0.657170        -0.443468           -0.449428
# 93022            -0.657170        -0.443468           -0.449428
# 93023            -0.469071        -0.443468           -0.449428
#
#        effective_cloud_cover:p_45  elevation:m_45  fresh_snow_12h:cm_45  \
# 0                        0.955622       -0.685740             -0.149375
# 1                       -1.911177        1.599325             -0.149375
# 2                        0.200437       -0.685740             -0.149375
# 3                       -1.673004        1.599325             -0.149375
# 4                        0.955622       -0.558792             -0.149375
# ...                           ...             ...                   ...
# 93019                    0.955622       -0.558792             -0.149375
# 93020                    0.952718        1.599325             -0.149375
# 93021                   -1.597485       -0.558792             -0.149375
# 93022                   -0.511180       -0.685740             -0.149375
# 93023                    0.955622       -0.685740              5.316192
#
#        fresh_snow_1h:cm_45  fresh_snow_24h:cm_45  fresh_snow_3h:cm_45  \
# 0                -0.087254             -0.188512            -0.104687
# 1                -0.087254             -0.188512            -0.104687
# 2                -0.087254             -0.188512            -0.104687
# 3                -0.087254             -0.188512            -0.104687
# 4                -0.087254             -0.188512            -0.104687
# ...                    ...                   ...                  ...
# 93019            -0.087254             -0.188512            -0.104687
# 93020            -0.087254             -0.188512            -0.104687
# 93021            -0.087254             -0.188512            -0.104687
# 93022            -0.087254             -0.188512            -0.104687
# 93023             4.379774              3.298091             4.530217
#
#        fresh_snow_6h:cm_45  is_day:idx_45  is_in_shadow:idx_45  \
# 0                -0.121861      -0.967359             0.879292
# 1                -0.121861       1.033731            -1.137266
# 2                -0.121861       1.033731            -1.137266
# 3                -0.121861       1.033731            -1.137266
# 4                -0.121861      -0.967359             0.879292
# ...                    ...            ...                  ...
# 93019            -0.121861       1.033731            -1.137266
# 93020            -0.121861       1.033731            -1.137266
# 93021            -0.121861      -0.967359             0.879292
# 93022            -0.121861      -0.967359             0.879292
# 93023             5.064081       1.033731            -1.137266
#
#        msl_pressure:hPa_45  precip_5min:mm_45  precip_type_5min:idx_45  \
# 0                 0.924489            -0.1732                -0.220466
# 1                 0.175581            -0.1732                -0.220466
# 2                 1.696322            -0.1732                -0.220466
# 3                 0.565322            -0.1732                -0.220466
# 4                -0.275289            -0.1732                -0.220466
# ...                    ...                ...                      ...
# 93019            -0.099526            -0.1732                -0.220466
# 93020            -0.619176            -0.1732                -0.220466
# 93021             1.337155            -0.1732                -0.220466
# 93022             1.062048            -0.1732                -0.220466
# 93023            -1.467432            -0.1732                -0.220466
#
#        pressure_100m:hPa_45  pressure_50m:hPa_45  prob_rime:p_45  \
# 0                  0.998163             0.983656       -0.138767
# 1                  0.075452             0.057443       -0.138767
# 2                  1.682509             1.718507       -0.138767
# 3                  0.444535             0.432519       -0.138767
# 4                 -0.232119            -0.233434       -0.138767
# ...                     ...                  ...             ...
# 93019             -0.016820            -0.034414       -0.138767
# 93020             -0.731921            -0.738645       -0.138767
# 93021              1.367247             1.381700       -0.138767
# 93022              1.128882             1.121439       -0.138767
# 93023             -1.431642            -1.419908       -0.138767
#
#        rain_water:kgm2_45  relative_humidity_1000hPa:p_45  \
# 0               -0.227180                        1.195156
# 1               -0.227180                       -0.419125
# 2               -0.227180                        0.177457
# 3               -0.227180                       -1.001669
# 4               -0.227180                        0.795095
# ...                   ...                             ...
# 93019            9.246385                        1.482919
# 93020            4.509603                        1.223230
# 93021           -0.227180                       -0.931483
# 93022           -0.227180                        0.479258
# 93023           -0.227180                       -0.138380
#
#        sfc_pressure:hPa_45  snow_density:kgm3_45  snow_depth:cm_45  \
# 0                 0.974665             -0.216696         -0.154067
# 1                 0.037510             -0.216696         -0.154067
# 2                 1.759429             -0.216696         -0.154067
# 3                 0.418466             -0.216696         -0.154067
# 4                -0.229160             -0.216696         -0.154067
# ...                    ...                   ...               ...
# 93019            -0.046299             -0.216696         -0.154067
# 93020            -0.754876             -0.216696         -0.154067
# 93021             1.393716             -0.216696         -0.154067
# 93022             1.119425             -0.216696         -0.154067
# 93023            -1.410123             -0.216696         -0.154067
#
#        snow_drift:idx_45  snow_melt_10min:mm_45  snow_water:kgm2_45  \
# 0              -0.004639              -0.063921           -0.374735
# 1              -0.004639              -0.063921           -0.374735
# 2              -0.004639              -0.063921           -0.374735
# 3              -0.004639              -0.063921           -0.374735
# 4              -0.004639              -0.063921            2.116168
# ...                  ...                    ...                 ...
# 93019          -0.004639              -0.063921            1.701017
# 93020          -0.004639              -0.063921            4.607070
# 93021          -0.004639              -0.063921           -0.374735
# 93022          -0.004639              -0.063921           -0.374735
# 93023          -0.004639              -0.063921            2.116168
#
#        sun_azimuth:d_45  sun_elevation:d_45  \
# 0             -1.687424           -0.411826
# 1             -1.179270            0.459092
# 2             -0.227917            0.174437
# 3              0.556527            0.531901
# 4             -0.785701           -0.359885
# ...                 ...                 ...
# 93019         -0.831634            0.372413
# 93020         -0.886515            0.663649
# 93021          1.375370           -1.025788
# 93022          1.676499           -0.730220
# 93023         -0.089661            0.237333
#
#        super_cooled_liquid_water:kgm2_45  t_1000hPa:K_45  \
# 0                               0.399658        0.900715
# 1                              -0.527065        2.020905
# 2                              -0.527065       -2.337083
# 3                              -0.527065        1.146236
# 4                               0.399658       -0.219470
# ...                                  ...             ...
# 93019                           2.253103        1.146236
# 93020                           0.399658        0.885374
# 93021                          -0.527065       -0.787238
# 93022                          -0.527065        0.256227
# 93023                           0.399658       -1.201551
#
#        total_cloud_cover:p_45  visibility:m_45  wind_speed_10m:ms_45  \
# 0                    0.768489        -1.102563             -0.872096
# 1                   -2.081249         0.816756             -1.042160
# 2                    0.183927        -0.388191             -0.872096
# 3                   -1.639905         1.117837              0.885235
# 4                    0.768489        -1.694251              0.941923
# ...                       ...              ...                   ...
# 93019                0.768489        -1.786764             -0.928784
# 93020                0.768489        -1.785625              0.148290
# 93021               -1.449923         0.692750             -0.758719
# 93022               -0.707529        -0.691811             -1.042160
# 93023                0.768489        -0.686866              1.282052
#
#        wind_speed_u_10m:ms_45  wind_speed_v_10m:ms_45  \
# 0                    0.297381               -0.416607
# 1                   -0.450831                0.166948
# 2                   -0.130168                0.432201
# 3                   -1.626592                0.909656
# 4                    1.366256                0.326100
# ...                       ...                     ...
# 93019                0.154865                0.113898
# 93020                0.903077               -0.734911
# 93021               -0.807122               -0.045254
# 93022                0.190494               -0.151355
# 93023               -0.237056               -3.175236
#
#        wind_speed_w_1000hPa:ms_45       day  hour
# 0                        0.000172  0.427953    23
# 1                        0.000172  0.090168     3
# 2                        0.000172 -1.470947     9
# 3                        0.000172  0.911808    14
# 4                        0.000172 -1.178808     5
# ...                           ...       ...   ...
# 93019                    0.000172  0.692704     5
# 93020                    0.000172  0.464471     5
# 93021                    0.000172  0.930067    20
# 93022                    0.000172  0.637928    22
# 93023                    0.000172 -1.498335    10
#
# [93024 rows x 183 columns]

# %%
numModels = 10

models = []

for i in range(numModels):
    models.append(tf.keras.models.Sequential([
        #tf.keras.layers.GaussianNoise(stddev=0.1, seed=42),
        tf.keras.layers.Dense(150, activation="tanh"),
        tf.keras.layers.Dense(120, activation="relu"),
        tf.keras.layers.Dense(90, activation="relu"),
        tf.keras.layers.Dense(60, activation="relu"),
        tf.keras.layers.Dense(1, activation="relu"),
    ]))

# %%
i = 0
while(i < numModels):
    
    models[i].compile(
        optimizer=tf.keras.optimizers.experimental.Adadelta(learning_rate=1, 
                                                            #weight_decay=0.0001
                                                            ),
        loss="mean_absolute_error"
    )

    history = models[i].fit(x = trainsetX,
                        y= trainsetY,
                        batch_size = 1000,
                        epochs=100,
                        verbose=0
                    )
    
    #retry if model is nonsensical
    loss = models[i].evaluate(evalsetX, evalsetY)
    if(loss > 200):
        continue
    
    print(i, " complete")
    i+=1
# Out:
# 251/251 [==============================] - 1s 3ms/step - loss: 78.6133
# 0  complete
# 251/251 [==============================] - 1s 3ms/step - loss: 78.6055
# 1  complete
# 251/251 [==============================] - 1s 3ms/step - loss: 81.8283
# 2  complete
# 251/251 [==============================] - 1s 2ms/step - loss: 83.0844
# 3  complete
# 251/251 [==============================] - 1s 3ms/step - loss: 80.7020
# 4  complete
# 251/251 [==============================] - 1s 2ms/step - loss: 289.7400
# 251/251 [==============================] - 1s 3ms/step - loss: 289.7400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/sondrekolberg/Documents/School/MaskinLæring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> while(i < numModels):
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     models[i].compile(
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>         optimizer=tf.keras.optimizers.experimental.Adadelta(learning_rate=1,
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>                                                             #weight_decay=0.0001
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>                                                             ),
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>         loss="mean_absolute_error"
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     )
# ---> <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>     history = models[i].fit(x = trainsetX,
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>                         y= trainsetY,
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>                         batch_size = 1000,
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>                         epochs=100,
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a>                         verbose=0
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a>                     )
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     #retry if model is nonsensical
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a>     loss = models[i].evaluate(evalsetX, evalsetY)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:904, in Function._call(self, *args, **kwds)
#     900     pass  # Fall through to cond-based initialization.
#     901   else:
#     902     # Lifting succeeded, so variables are initialized and we can run the
#     903     # no_variable_creation function.
# --> 904     return tracing_compilation.call_function(
#     905         args, kwds, self._no_variable_creation_config
#     906     )
#     907 else:
#     908   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     909       *args, **kwds
#     910   )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     181   _set_arg_keywords(concrete_function)
#     183 if not tracing_options.bind_graph_to_function:
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:284, in _maybe_define_function(args, kwargs, tracing_options)
#     282 else:
#     283   target_func_type = lookup_func_type
# --> 284 concrete_function = _create_concrete_function(
#     285     target_func_type, lookup_func_context, func_graph, tracing_options
#     286 )
#     288 if tracing_options.function_cache is not None:
#     289   tracing_options.function_cache.add(
#     290       concrete_function, current_func_context
#     291   )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:308, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303 with func_graph.as_default():
#     304   placeholder_bound_args = function_type.placeholder_arguments(
#     305       placeholder_context
#     306   )
# --> 308 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     309     tracing_options.name,
#     310     tracing_options.python_function,
#     311     placeholder_bound_args.args,
#     312     placeholder_bound_args.kwargs,
#     313     None,
#     314     func_graph=func_graph,
#     315     arg_names=function_type_utils.to_arg_names(function_type),
#     316     create_placeholders=False,
#     317 )
#     319 transform.apply_func_graph_transforms(traced_func_graph)
#     321 graph_capture_container = traced_func_graph.function_captures
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:597, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     593 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     594   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     595   # the function a weak reference to itself to avoid a reference cycle.
#     596   with OptionalXlaContext(compile_with_xla):
# --> 597     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     598   return out
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /var/folders/bm/37km6rb530l8y0vv0znc0zb00000gn/T/__autograph_generated_file0x6aofk1.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:1360, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1356     run_step = tf.function(
#    1357         run_step, jit_compile=True, reduce_retracing=True
#    1358     )
#    1359 data = next(iterator)
# -> 1360 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1361 outputs = reduce_per_replica(
#    1362     outputs,
#    1363     self.distribute_strategy,
#    1364     reduction=self.distribute_reduction_method,
#    1365 )
#    1366 return outputs
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:1679, in StrategyBase.run(***failed resolving arguments***)
#    1674 with self.scope():
#    1675   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1676   # applied when the caller is also in Eager mode.
#    1677   fn = autograph.tf_convert(
#    1678       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1679   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3269, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3267   kwargs = {}
#    3268 with self._container_strategy().scope():
# -> 3269   return self._call_for_each_replica(fn, args, kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:4067, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4065 def _call_for_each_replica(self, fn, args, kwargs):
#    4066   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4067     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:1349, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1348 def run_step(data):
# -> 1349     outputs = model.train_step(data)
#    1350     # Ensure counter is updated only if `train_step` succeeds.
#    1351     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:1130, in Model.train_step(self, data)
#    1128 self._validate_target_and_loss(y, loss)
#    1129 # Run backwards pass.
# -> 1130 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1131 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:544, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     523 """Minimize `loss` by updating `var_list`.
#     524
#     525 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541   None
#     542 """
#     543 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 544 self.apply_gradients(grads_and_vars)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:1223, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1221 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223 return super().apply_gradients(grads_and_vars, name=name)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:652, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     650 self._apply_weight_decay(trainable_variables)
#     651 grads_and_vars = list(zip(grads, trainable_variables))
# --> 652 iteration = self._internal_apply_gradients(grads_and_vars)
#     654 # Apply variable constraints after applying gradients.
#     655 for variable in trainable_variables:
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:1253, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1249 if self._mesh or self._run_with_dtensor:
#    1250     # Skip any usage of strategy logic for DTensor
#    1251     return super()._internal_apply_gradients(grads_and_vars)
# -> 1253 return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254     self._distributed_apply_gradients_fn,
#    1255     self._distribution_strategy,
#    1256     grads_and_vars,
#    1257 )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:1345, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1342         return self._update_step(grad, var)
#    1344 for grad, var in grads_and_vars:
# -> 1345     distribution.extended.update(
#    1346         var, apply_grad_to_update_var, args=(grad,), group=False
#    1347     )
#    1349 if self.use_ema:
#    1350     _, var_list = zip(*grads_and_vars)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3013, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3011     return self._update(var, fn, args, kwargs, group)
#    3012 else:
# -> 3013   return self._replica_ctx_update(
#    3014       var, fn, args=args, kwargs=kwargs, group=group)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:2892, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2889 def merge_fn(_, *merged_args, **merged_kwargs):
#    2890   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2892 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3484, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3480   kwargs = {}
#    3482 merge_fn = autograph.tf_convert(
#    3483     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3484 return self._merge_call(merge_fn, args, kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3491, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3488 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3489     _CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3490 try:
# -> 3491   return merge_fn(self._strategy, *args, **kwargs)
#    3492 finally:
#    3493   _pop_per_thread_mode()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:2890, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2889 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2890   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3011, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3008   fn = autograph.tf_convert(
#    3009       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3010   with self._container_strategy().scope():
# -> 3011     return self._update(var, fn, args, kwargs, group)
#    3012 else:
#    3013   return self._replica_ctx_update(
#    3014       var, fn, args=args, kwargs=kwargs, group=group)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:4081, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4078 def _update(self, var, fn, args, kwargs, group):
#    4079   # The implementations of _update() and _update_non_slot() are identical
#    4080   # except _update() passes `var` as the first argument to `fn()`.
# -> 4081   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:4087, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4083 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4084   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4085   # once that value is used for something.
#    4086   with UpdateContext(colocate_with):
# -> 4087     result = fn(*args, **kwargs)
#    4088     if should_group:
#    4089       return result
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:1342, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1340     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341 else:
# -> 1342     return self._update_step(grad, var)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/optimizer.py:241, in _BaseOptimizer._update_step(self, gradient, variable)
#     232 if self._var_key(variable) not in self._index_dict:
#     233     raise KeyError(
#     234         f"The optimizer cannot recognize variable {variable.name}. "
#     235         "This usually means you are trying to call the optimizer to "
#    (...)
#     239         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240     )
# --> 241 self.update_step(gradient, variable)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/optimizers/adadelta.py:144, in Adadelta.update_step(self, grad, variable)
#     138     accumulated_delta_var.assign(
#     139         rho * accumulated_delta_var + (1 - rho) * delta_var * delta_var
#     140     )
#     141 else:
#     142     # Dense gradients.
#     143     accumulated_grad.assign(
# --> 144         rho * accumulated_grad + (1 - rho) * grad * grad
#     145     )
#     146     delta_var = (
#     147         -rms(accumulated_delta_var) * grad / rms(accumulated_grad)
#     148     )
#     149     accumulated_delta_var.assign(
#     150         rho * accumulated_delta_var + (1 - rho) * delta_var * delta_var
#     151     )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/variables.py:1013, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1011 def _run_op(a, *args, **kwargs):
#    1012   # pylint: disable=protected-access
# -> 1013   return tensor_oper(a.value(), *args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:632, in BaseResourceVariable.value(self)
#     630   return self._cached_value
#     631 with ops.colocate_with(None, ignore_existing=True):
# --> 632   return self._read_variable_op()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:793, in BaseResourceVariable._read_variable_op(self, no_copy)
#     791       result = read_and_set_handle(no_copy)
#     792 else:
# --> 793   result = read_and_set_handle(no_copy)
#     795 if not context.executing_eagerly():
#     796   # Note that if a control flow context is active the input of the read op
#     797   # might not actually be the handle. This line bypasses it.
#     798   record.record_operation(
#     799       "ReadVariableOp", [result], [self.handle],
#     800       backward_function=lambda x: [x],
#     801       forward_function=lambda x: [x])
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:783, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     781 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     782   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 783 result = gen_resource_variable_ops.read_variable_op(
#     784     self.handle, self._dtype)
#     785 _maybe_set_handle_data(self._dtype, self.handle, result)
#     786 return result
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:547, in read_variable_op(resource, dtype, name)
#     545 # Add nodes to the TensorFlow graph.
#     546 dtype = _execute.make_type(dtype, "dtype")
# --> 547 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     548       "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#     549 _result = _outputs[:]
#     550 if _execute.must_record_gradient():
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:698, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     696 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     697 preferred_dtype = preferred_dtype or dtype_hint
# --> 698 return tensor_conversion_registry.convert(
#     699     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     700 )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:592, in _EagerTensorBase.__tf_tensor__(self, dtype, name)
#     586   if not graph.building_function:
#     587     raise RuntimeError(
#     588         _add_error_prefix(
#     589             "Attempting to capture an EagerTensor without "
#     590             "building a function.",
#     591             name=name))
# --> 592   return graph.capture(self, name=name)
#     593 return super().__tf_tensor__(dtype, name)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:675, in FuncGraph.capture(self, tensor, name, shape)
#     674 def capture(self, tensor, name=None, shape=None):
# --> 675   return self._function_captures.capture_by_value(self, tensor, name)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/core/function/capture/capture_container.py:141, in FunctionCaptures.capture_by_value(self, graph, tensor, name)
#     138     return graph_const
#     140   # Large EagerTensors and resources are captured with Placeholder ops
# --> 141   return self._create_placeholder_helper(graph, tensor, name)
#     143 if tensor.graph is not graph:
#     144   graph._validate_in_scope(tensor)  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/core/function/capture/capture_container.py:285, in FunctionCaptures._create_placeholder_helper(self, graph, tensor, name)
#     279   composite_device_name = None
#     280 placeholder_ctx = trace_type.InternalPlaceholderContext(
#     281     graph,
#     282     with_none_control_dependencies=True,
#     283     composite_device_name=composite_device_name,
#     284 )
# --> 285 placeholder = spec.placeholder_value(placeholder_ctx)
#     286 self.add_or_replace(
#     287     key=id(tensor), external=tensor, internal=placeholder, is_by_ref=False
#     288 )
#     289 graph.inputs.append(placeholder)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/tensor.py:1020, in TensorSpec.placeholder_value(self, placeholder_context)
#    1016 if placeholder_context.with_none_control_dependencies:
#    1017   # Note: setting ops.control_dependencies(None) ensures we always put
#    1018   # capturing placeholders outside of any control flow context.
#    1019   with context_graph.control_dependencies(None):
# -> 1020     placeholder = self._graph_placeholder(context_graph, name=name)
#    1021 else:
#    1022   placeholder = self._graph_placeholder(context_graph, name=name)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/tensor.py:1060, in TensorSpec._graph_placeholder(self, graph, name)
#    1058 attrs = {"dtype": dtype_value, "shape": shape}
#    1059 try:
# -> 1060   op = graph._create_op_internal(  # pylint: disable=protected-access
#    1061       "Placeholder", [], [dtype], input_types=[],
#    1062       attrs=attrs, name=name)
#    1063 except ValueError as e:
#    1064   # TODO(b/262413656) Sometimes parameter names are not valid op names, in
#    1065   # which case an unnamed placeholder is created instead. Update this logic
#    1066   # to sanitize the name instead of falling back on unnamed placeholders.
#    1067   logging.warning(e)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:2657, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2654 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2655 # Session.run call cannot occur between creating and mutating the op.
#    2656 with self._mutation_lock():
# -> 2657   ret = Operation.from_node_def(
#    2658       node_def,
#    2659       self,
#    2660       inputs=inputs,
#    2661       output_types=dtypes,
#    2662       control_inputs=control_inputs,
#    2663       input_types=input_types,
#    2664       original_op=self._default_original_op,
#    2665       op_def=op_def,
#    2666   )
#    2667   self._create_op_helper(ret, compute_device=compute_device)
#    2668 return ret
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:1161, in Operation.from_node_def(***failed resolving arguments***)
#    1158     control_input_ops.append(control_op)
#    1160 # Initialize c_op from node_def and other inputs
# -> 1161 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1162 self = Operation(c_op, SymbolicTensor)
#    1163 self._init(g)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:991, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#     989 # pylint: disable=protected-access
#     990 with graph._c_graph.get() as c_graph:
# --> 991   op_desc = pywrap_tf_session.TF_NewOperation(c_graph,
#     992                                               compat.as_str(node_def.op),
#     993                                               compat.as_str(node_def.name))
#     994 if node_def.device:
#     995   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:

# %%
#!ReWrite
def evaluate_models(models, X, Y):
    preds = X.iloc[:,1:2]

    for i in range(len(models)):
        preds[str(i)] = models[i].predict(X)
        
    
    preds = preds.iloc[:,1:]
    
    
    preds["final"] = preds.mean(axis=1)
    preds["losses"] = (preds["final"] - Y["pv_measurement"]).apply(lambda a : np.abs(a))
    return preds["losses"].mean()

# %%
def get_predictions(models, X):
    preds = X.iloc[:,1:2]

    for i in range(len(models)):
        preds[str(i)] = models[i].predict(X)
        
    
    preds = preds.iloc[:,1:]
    return(preds)

# %%
print("entire:")
results = evaluate_models(models ,evalsetX, evalsetY)
print(results)

print("may june july:")
resultsMayJuneJuly = evaluate_models(models ,evalsetX[evalsetIndexMayJuneJuly], evalsetY[evalsetIndexMayJuneJuly])
print(resultsMayJuneJuly)
# Out:
# entire:
# 251/251 [==============================] - 2s 5ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 251/251 [==============================] - 1s 3ms/step
# 71.89782553480394
# may june july:
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 3ms/step
# 151.4767432667944
# location A
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location_A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/sondrekolberg/Documents/School/MaskinLæring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> print(resultsMayJuneJuly)
#       <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> print("location A")
# ---> <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> resultA = evaluate_models(models ,evalsetX[evalsetX["location_A"].apply(lambda a : a == 1)],
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>                          evalsetY[evalsetX["location_A"].apply(lambda a : a == 1)])
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> print(resultA)
#      <a href='vscode-notebook-cell:/Users/sondrekolberg/Documents/School/MaskinL%C3%A6ring/Project/tdt4173-machine-learning/Ensamble2withourLocation.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> print("location B")
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'location_A'

# %%
print("location A")
resultA = evaluate_models(models ,evalsetX[evalsetX["location_A"].apply(lambda a : a == 1)], 
                         evalsetY[evalsetX["location_A"].apply(lambda a : a == 1)])
print(resultA)

print("location B")
resultB = evaluate_models(models ,evalsetX[evalsetX["location_B"].apply(lambda a : a == 1)], 
                         evalsetY[evalsetX["location_B"].apply(lambda a : a == 1)])
print(resultB)

print("location C")
resultC = evaluate_models(models ,evalsetX[evalsetX["location_C"].apply(lambda a : a == 1)], 
                         evalsetY[evalsetX["location_C"].apply(lambda a : a == 1)])
print(resultC)

# %%
X_test_estimated_a = pd.read_parquet('A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('C/X_test_estimated.parquet')

X_test_estimated_a["location"] = "A"
X_test_estimated_b["location"] = "B"
X_test_estimated_c["location"] = "C"

X_test_raw = pd.concat([
                     X_test_estimated_a,
                     X_test_estimated_b,
                     X_test_estimated_c])

#feature indicating time between date_calc and date_forecast
X_test_raw["calc_time"] =(X_test_raw["date_forecast"] - X_test_raw["date_calc"]).astype('timedelta64[s]')

#fill nans
X_test_raw["snow_density:kgm3"] = X_test_raw["snow_density:kgm3"].apply(
    lambda a : np.isnan(a)
    ).map({True: 0, False: 1})
X_test_raw["ceiling_height_agl:m"] = X_test_raw["ceiling_height_agl:m"].apply(
    lambda a : -1000 if np.isnan(a) else a
)
X_test_raw["cloud_base_agl:m"] = X_test_raw["ceiling_height_agl:m"].apply(
    lambda a : -1000 if np.isnan(a) else a
)

#create seperate dataframes for measurments at minute 00, 15, 30 and 45
X_test00 = X_test_raw[X_test_raw["date_forecast"].apply(lambda time: time.minute == 0)].reset_index().iloc[:,1:]
X_test15 = X_test_raw[X_test_raw["date_forecast"].apply(lambda time: time.minute == 15)].reset_index().iloc[:,1:]
X_test30 = X_test_raw[X_test_raw["date_forecast"].apply(lambda time: time.minute == 30)].reset_index().iloc[:,1:]
X_test45 = X_test_raw[X_test_raw["date_forecast"].apply(lambda time: time.minute == 45)].reset_index().iloc[:,1:]

#remove redundant data
X_test15 = X_test15.iloc[:,2:-2]
X_test30 = X_test30.iloc[:,2:-2]
X_test45 = X_test45.iloc[:,2:-2]

#join observations into single sample
X_test_estimated = X_test00.join(X_test15, lsuffix="_00", rsuffix="_15").join(X_test30.join(X_test45, lsuffix="_30", rsuffix="_45"))


X_test_estimated = X_test_estimated.rename(columns={"date_forecast" : "time"})

parse_dates = ['time']
X_test_targets = pd.read_csv("test.csv", parse_dates=parse_dates)

X_test = pd.merge(X_test_estimated, X_test_targets, on=["time", "location"], how="right").iloc[:,:-2]


X_test["day"] = X_test["time"].dt.day_of_year
X_test["hour"] = X_test["time"].dt.hour

#X_test["location_A"] = X_test["location"].apply(lambda a : a == "A").map({True: 1, False: 0})
#X_test["location_B"] = X_test["location"].apply(lambda a : a == "B").map({True: 1, False: 0})
#X_test["location_C"] = X_test["location"].apply(lambda a : a == "C").map({True: 1, False: 0})

X_test = X_test.drop("location", axis=1)

X_test = X_test.iloc[:,2:]


X_test.iloc[:,:-1] = ((X_test.iloc[:,:-1]-dataMean[:-1])/dataStd[:-1]).fillna(value=0)

display(X_test)
# Out:
# /var/folders/bm/37km6rb530l8y0vv0znc0zb00000gn/T/ipykernel_28002/2012859473.py:63: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized.
#   X_test.iloc[:,:-1] = ((X_test.iloc[:,:-1]-dataMean[:-4])/dataStd[:-1]).fillna(value=0)
#       absolute_humidity_2m:gm3_00  air_density_2m:kgm3_00  \
# 0                       -0.595904               -0.633138
# 1                       -0.632742               -0.633138
# 2                       -0.669581               -0.670004
# 3                       -0.706420               -0.743737
# 4                       -0.780097               -0.780603
# ...                           ...                     ...
# 2155                     0.840800                0.878386
# 2156                     0.914477                0.952119
# 2157                     1.024993                1.025852
# 2158                     1.098670                1.099585
# 2159                     1.098670                1.099585
#
#       ceiling_height_agl:m_00  clear_sky_energy_1h:J_00  clear_sky_rad:W_00  \
# 0                   -0.633262                 -0.633106            0.834929
# 1                   -0.633262                 -0.669973            0.862243
# 2                   -0.707012                 -0.706840            0.780297
# 3                   -0.743887                 -0.743707            0.725662
# 4                   -0.780762                 -0.780574            0.725662
# ...                       ...                       ...                 ...
# 2155                 0.878619                  0.915310           -1.623536
# 2156                 0.952370                  0.989044           -1.541587
# 2157                 1.062995                  1.099645           -1.459637
# 2158                 1.099870                  1.099645           -1.350374
# 2159                 1.062995                  1.062778           -1.323056
#
#       cloud_base_agl:m_00  dew_or_rime:idx_00  dew_point_2m:K_00  \
# 0                0.863015            0.863208           0.862931
# 1                0.835677            0.835861           0.808253
# 2                0.780998            0.781165           0.753576
# 3                0.726315            0.726465           0.726235
# 4                0.698977            0.699119           0.671558
# ...                   ...                 ...                ...
# 2155            -1.624914           -1.598153          -1.570247
# 2156            -1.515552           -1.516107          -1.488229
# 2157            -1.433535           -1.406714          -1.378871
# 2158            -1.351515           -1.324668          -1.324194
# 2159            -1.324174           -1.324668          -1.324194
#
#       diffuse_rad:W_00  diffuse_rad_1h:J_00  direct_rad:W_00  \
# 0             1.486148            -0.382669        -0.469433
# 1             1.594321            -1.083697        -0.262383
# 2             1.702494            -0.173977        -0.187439
# 3             1.810667             0.128249         0.038956
# 4             1.918840             0.134297         0.013175
# ...                ...                  ...              ...
# 2155          3.540625             0.577483         0.473783
# 2156          3.648798             0.539586         0.360658
# 2157          3.756971             0.197264         0.060701
# 2158          3.865144             0.014887        -0.074278
# 2159          3.973317             0.017892        -0.072060
#
#       direct_rad_1h:J_00  effective_cloud_cover:p_00  elevation:m_00  \
# 0              -0.470753                   -0.467769       -0.627834
# 1              -0.262368                   -0.259939       -0.627834
# 2              -0.111477                   -0.034225       -0.627834
# 3               0.042414                    0.045564       -0.627834
# 4              -0.015483                   -0.044116       -0.554985
# ...                  ...                         ...             ...
# 2155            0.469065                    0.460128        0.122098
# 2156            0.279235                    0.194994       -0.299286
# 2157            0.017272                   -0.026450       -0.540086
# 2158           -0.072282                   -0.069630       -0.626155
# 2159           -0.070818                   -0.068900       -0.627834
#
#       fresh_snow_12h:cm_00  fresh_snow_1h:cm_00  fresh_snow_24h:cm_00  \
# 0                -0.627839            -0.627835             -0.627838
# 1                -0.627839            -0.627835             -0.627838
# 2                -0.627839            -0.627835             -0.627838
# 3                -0.626218            -0.615336             -0.592602
# 4                -0.498582            -0.427133             -0.339631
# ...                    ...                  ...                   ...
# 2155              0.003236            -0.107507             -0.208797
# 2156             -0.377811            -0.443670             -0.497193
# 2157             -0.574667            -0.600774             -0.616270
# 2158             -0.627839            -0.627835             -0.627838
# 2159             -0.627839            -0.627835             -0.627838
#
#       fresh_snow_3h:cm_00  fresh_snow_6h:cm_00  is_day:idx_00  \
# 0               -0.626244            -0.626183      -0.626218
# 1               -0.626244            -0.626183      -0.626218
# 2               -0.626244            -0.626183      -0.626218
# 3               -0.626244            -0.605178      -0.561013
# 4               -0.438066            -0.349613      -0.244615
# ...                   ...                  ...            ...
# 2155            -0.113350            -0.215267      -0.306757
# 2156            -0.451195            -0.503652      -0.543946
# 2157            -0.604801            -0.626183      -0.626218
# 2158            -0.626244            -0.626183      -0.626218
# 2159            -0.626244            -0.626183      -0.626218
#
#       is_in_shadow:idx_00  msl_pressure:hPa_00  precip_5min:mm_00  \
# 0               -0.626252            -0.382669          -0.469433
# 1               -0.626252            -1.083697          -0.262383
# 2               -0.626252            -0.173977          -0.187439
# 3               -0.508093             0.128249           0.038956
# 4               -0.126921             0.134297           0.013175
# ...                   ...                  ...                ...
# 2155            -0.385558             0.577483           0.473783
# 2156            -0.576362             0.539586           0.360658
# 2157            -0.626252             0.197264           0.060701
# 2158            -0.626252             0.014887          -0.074278
# 2159            -0.626252             0.017892          -0.072060
#
#       precip_type_5min:idx_00  pressure_100m:hPa_00  pressure_50m:hPa_00  \
# 0                   -0.470753             -0.467769                  0.0
# 1                   -0.262368             -0.259939                  0.0
# 2                   -0.111477             -0.034225                  0.0
# 3                    0.042414              0.045564                  0.0
# 4                   -0.015483             -0.044116                  0.0
# ...                       ...                   ...                  ...
# 2155                 0.469065              0.460128                  0.0
# 2156                 0.279235              0.194994                  0.0
# 2157                 0.017272             -0.026450                  0.0
# 2158                -0.072282             -0.069630                  0.0
# 2159                -0.070818             -0.068900                  0.0
#
#       prob_rime:p_00  rain_water:kgm2_00  relative_humidity_1000hPa:p_00  \
# 0          -0.028554           -0.028313                       -0.027486
# 1          -0.028554           -0.028313                       -0.027486
# 2          -0.028554           -0.028313                       -0.027486
# 3          -0.028554           -0.028313                       -0.027486
# 4          -0.028554           -0.028313                       -0.027486
# ...              ...                 ...                             ...
# 2155       -0.028554           -0.028313                       -0.027486
# 2156       -0.028554           -0.028313                       -0.027486
# 2157       -0.028554           -0.028313                       -0.027486
# 2158       -0.028554           -0.028313                       -0.027486
# 2159       -0.028554           -0.028313                       -0.027486
#
#       sfc_pressure:hPa_00  snow_density:kgm3_00  snow_depth:cm_00  \
# 0               -0.026713             -0.517627         -0.517958
# 1               -0.026713             -0.532260         -0.547239
# 2               -0.026713             -0.590784         -0.605797
# 3               -0.026713             -0.649314         -0.664355
# 4               -0.026713             -0.722471         -0.708277
# ...                   ...                   ...               ...
# 2155            -0.026713              0.930882          0.946016
# 2156            -0.026713              0.974774          0.989934
# 2157            -0.026713              1.018671          1.033851
# 2158            -0.026713              1.077196          1.077773
# 2159            -0.026713              1.062563          1.063132
#
#       snow_drift:idx_00  snow_melt_10min:mm_00  snow_water:kgm2_00  \
# 0             -0.532710              -0.532568           -0.651235
# 1             -0.561997              -0.576489           -0.651235
# 2             -0.620566              -0.635046           -0.651235
# 3             -0.679135              -0.693602           -0.651235
# 4             -0.708422              -0.708243           -0.133490
# ...                 ...                    ...                 ...
# 2155           0.946190               0.960648            0.029749
# 2156           1.004759               1.004569           -0.326408
# 2157           1.048685               1.063126           -0.568792
# 2158           1.077972               1.077766           -0.651235
# 2159           1.063328               1.048485           -0.651235
#
#       sun_azimuth:d_00  sun_elevation:d_00  super_cooled_liquid_water:kgm2_00  \
# 0            -0.648966           -0.643902                          -0.649161
# 1            -0.648966           -0.643902                          -0.649161
# 2            -0.648966           -0.643902                          -0.649161
# 3            -0.597925           -0.432251                          -0.295139
# 4             0.044198            0.214189                           0.401377
# ...                ...                 ...                                ...
# 2155         -0.075994           -0.177941                          -0.249034
# 2156         -0.397056           -0.458502                          -0.497672
# 2157         -0.648966           -0.643902                          -0.649161
# 2158         -0.648966           -0.643902                          -0.649161
# 2159         -0.648966           -0.643902                          -0.649161
#
#       t_1000hPa:K_00  total_cloud_cover:p_00  visibility:m_00  \
# 0          -0.658524               -0.656967        -0.653964
# 1          -0.658524               -0.656967        -0.653964
# 2          -0.658524               -0.656967        -0.653964
# 3          -0.658524               -0.631340        -0.546764
# 4          -0.396493               -0.280392        -0.110744
# ...              ...                     ...              ...
# 2155        0.264405                0.146314         0.030810
# 2156       -0.149611               -0.239632        -0.323951
# 2157       -0.452422               -0.529378        -0.560214
# 2158       -0.616985               -0.656967        -0.653964
# 2159       -0.658524               -0.656967        -0.653964
#
#       wind_speed_10m:ms_00  wind_speed_u_10m:ms_00  wind_speed_v_10m:ms_00  \
# 0                -0.657170               -0.444504               -0.443498
# 1                -0.657170               -0.444504               -0.443498
# 2                -0.657170               -0.444504               -0.443498
# 3                -0.478031               -0.444504               -0.443498
# 4                 0.053963               -0.347113               -0.277510
# ...                    ...                     ...                     ...
# 2155             -0.057175               -0.301073               -0.310178
# 2156             -0.378447               -0.392267               -0.410831
# 2157             -0.580618               -0.444504               -0.443498
# 2158             -0.657170               -0.444504               -0.443498
# 2159             -0.657170               -0.444504               -0.443498
#
#       wind_speed_w_1000hPa:ms_00  calc_time  absolute_humidity_2m:gm3_15  \
# 0                      -0.440573  -0.443468                    -0.449899
# 1                      -0.440573  -0.443468                    -0.449899
# 2                      -0.440573  -0.443468                    -0.449899
# 3                      -0.417807  -0.392259                    -0.449899
# 4                      -0.182268  -0.068235                    -0.400659
# ...                          ...        ...                          ...
# 2155                   -0.323241  -0.363124                    -0.307607
# 2156                   -0.440573  -0.443468                    -0.350643
# 2157                   -0.440573  -0.443468                    -0.423319
# 2158                   -0.440573  -0.443468                    -0.449899
# 2159                   -0.440573  -0.443468                    -0.449899
#
#       air_density_2m:kgm3_15  ceiling_height_agl:m_15  \
# 0                  -0.449477                -0.448215
# 1                  -0.449477                -0.448215
# 2                  -0.449477                -0.448215
# 3                  -0.449477                -0.436708
# 4                  -0.365430                -0.305320
# ...                      ...                      ...
# 2155               -0.310052                -0.317627
# 2156               -0.365556                -0.388695
# 2157               -0.433043                -0.448215
# 2158               -0.449477                -0.448215
# 2159               -0.449477                -0.448215
#
#       clear_sky_energy_1h:J_15  clear_sky_rad:W_15  cloud_base_agl:m_15  \
# 0                    -0.449428            0.390542             0.287455
# 1                    -0.449428           -0.071723             0.203231
# 2                    -0.449428            0.781470             0.685341
# 3                    -0.423553            0.227893             0.101581
# 4                    -0.233348           -0.240079            -0.098814
# ...                        ...                 ...                  ...
# 2155                 -0.334537            0.644503             0.609830
# 2156                 -0.408661            0.496121             0.371679
# 2157                 -0.449428            0.050977             0.240987
# 2158                 -0.449428            0.941265             0.955439
# 2159                 -0.449428            0.941265             0.955439
#
#       dew_or_rime:idx_15  dew_point_2m:K_15  diffuse_rad:W_15  \
# 0               0.174406           0.055209         -0.685740
# 1               0.443202           0.636121         -0.685740
# 2               0.560070           0.403756         -0.685740
# 3              -0.021347          -0.136492         -0.685740
# 4               0.051695           0.200437         -0.685740
# ...                  ...                ...               ...
# 2155            0.571756           0.534461          1.599325
# 2156            0.256213           0.145250          1.599325
# 2157            0.460732           0.697117          1.599325
# 2158            0.960342           0.955622          1.599325
# 2159            0.960342           0.955622          1.599325
#
#       diffuse_rad_1h:J_15  direct_rad:W_15  direct_rad_1h:J_15  \
# 0               -0.685740        -0.685740           -0.685740
# 1               -0.685740        -0.685740           -0.685740
# 2               -0.685740        -0.685740           -0.685740
# 3               -0.685740        -0.685740           -0.685740
# 4               -0.685740        -0.685740           -0.685740
# ...                   ...              ...                 ...
# 2155             1.599325         1.599325            1.599325
# 2156             1.599325         1.599325            1.599325
# 2157             1.599325         1.599325            1.599325
# 2158             1.599325         1.599325            1.599325
# 2159             1.599325         1.599325            1.599325
#
#       effective_cloud_cover:p_15  elevation:m_15  fresh_snow_12h:cm_15  \
# 0                      -0.148871        -0.15017             -0.149072
# 1                      -0.148871        -0.15017             -0.149072
# 2                      -0.148871        -0.15017             -0.149072
# 3                      -0.148871        -0.15017             -0.149072
# 4                      -0.148871        -0.15017             -0.149072
# ...                          ...             ...                   ...
# 2155                   -0.148871        -0.15017             -0.149072
# 2156                   -0.148871        -0.15017             -0.149072
# 2157                   -0.148871        -0.15017             -0.149072
# 2158                   -0.148871        -0.15017             -0.149072
# 2159                   -0.148871        -0.15017             -0.149072
#
#       fresh_snow_1h:cm_15  fresh_snow_24h:cm_15  fresh_snow_3h:cm_15  \
# 0               -0.149375             -0.085506            -0.087599
# 1               -0.149375             -0.085506            -0.087599
# 2               -0.149375             -0.085506            -0.087599
# 3               -0.149375             -0.085506            -0.087599
# 4               -0.149375             -0.085506            -0.087599
# ...                   ...                   ...                  ...
# 2155            -0.149375             -0.085506            -0.087599
# 2156            -0.149375             -0.085506            -0.087599
# 2157            -0.149375             -0.085506            -0.087599
# 2158            -0.149375             -0.085506            -0.087599
# 2159            -0.149375             -0.085506            -0.087599
#
#       fresh_snow_6h:cm_15  is_day:idx_15  is_in_shadow:idx_15  \
# 0               -0.087486      -0.087254            -0.188709
# 1               -0.087486      -0.087254            -0.188709
# 2               -0.087486      -0.087254            -0.188709
# 3               -0.087486      -0.087254            -0.188709
# 4               -0.087486      -0.087254            -0.188709
# ...                   ...            ...                  ...
# 2155            -0.087486      -0.087254            -0.188709
# 2156            -0.087486      -0.087254            -0.188709
# 2157            -0.087486      -0.087254            -0.188709
# 2158            -0.087486      -0.087254            -0.188709
# 2159            -0.087486      -0.087254            -0.188709
#
#       msl_pressure:hPa_15  precip_5min:mm_15  precip_type_5min:idx_15  \
# 0               -0.189691          -0.188034                -0.188512
# 1               -0.189691          -0.188034                -0.188512
# 2               -0.189691          -0.188034                -0.188512
# 3               -0.189691          -0.188034                -0.188512
# 4               -0.189691          -0.188034                -0.188512
# ...                   ...                ...                      ...
# 2155            -0.189691          -0.188034                -0.188512
# 2156            -0.189691          -0.188034                -0.188512
# 2157            -0.189691          -0.188034                -0.188512
# 2158            -0.189691          -0.188034                -0.188512
# 2159            -0.189691          -0.188034                -0.188512
#
#       pressure_100m:hPa_15  pressure_50m:hPa_15  prob_rime:p_15  \
# 0                -0.103329            -0.104406       -0.104584
# 1                -0.103329            -0.104406       -0.104584
# 2                -0.103329            -0.104406       -0.104584
# 3                -0.103329            -0.104406       -0.104584
# 4                -0.103329            -0.104406       -0.104584
# ...                    ...                  ...             ...
# 2155             -0.103329            -0.104406       -0.104584
# 2156             -0.103329            -0.104406       -0.104584
# 2157             -0.103329            -0.104406       -0.104584
# 2158             -0.103329            -0.104406       -0.104584
# 2159             -0.103329            -0.104406       -0.104584
#
#       rain_water:kgm2_15  relative_humidity_1000hPa:p_15  sfc_pressure:hPa_15  \
# 0              -0.104687                       -0.120629            -0.121976
# 1              -0.104687                       -0.120629            -0.121976
# 2              -0.104687                       -0.120629            -0.121976
# 3              -0.104687                       -0.120629            -0.121976
# 4              -0.104687                       -0.120629            -0.121976
# ...                  ...                             ...                  ...
# 2155           -0.104687                       -0.120629            -0.121976
# 2156           -0.104687                       -0.120629            -0.121976
# 2157           -0.104687                       -0.120629            -0.121976
# 2158           -0.104687                       -0.120629            -0.121976
# 2159           -0.104687                       -0.120629            -0.121976
#
#       snow_density:kgm3_15  snow_depth:cm_15  snow_drift:idx_15  \
# 0                -0.121631         -0.121861          -0.967213
# 1                -0.121631         -0.121861          -0.967213
# 2                -0.121631         -0.121861          -0.967213
# 3                -0.121631         -0.121861          -0.967213
# 4                -0.121631         -0.121861           1.033887
# ...                    ...               ...                ...
# 2155             -0.121631         -0.121861           1.033887
# 2156             -0.121631         -0.121861           1.033887
# 2157             -0.121631         -0.121861           1.033887
# 2158             -0.121631         -0.121861          -0.967213
# 2159             -0.121631         -0.121861          -0.967213
#
#       snow_melt_10min:mm_15  snow_water:kgm2_15  sun_azimuth:d_15  \
# 0                 -0.967713           -0.966276         -0.967359
# 1                 -0.967713           -0.966276         -0.967359
# 2                 -0.967713           -0.966276         -0.967359
# 3                  1.033353            1.034890          1.033731
# 4                  1.033353            1.034890          1.033731
# ...                     ...                 ...               ...
# 2155               1.033353            1.034890          1.033731
# 2156               1.033353            1.034890          1.033731
# 2157              -0.967713           -0.966276         -0.967359
# 2158              -0.967713           -0.966276         -0.967359
# 2159              -0.967713           -0.966276         -0.967359
#
#       sun_elevation:d_15  super_cooled_liquid_water:kgm2_15  t_1000hPa:K_15  \
# 0               0.876756                           0.879292        0.879543
# 1               0.876756                           0.879292        0.879543
# 2               0.876756                           0.879292        0.879543
# 3               0.876756                           0.879292       -1.136943
# 4              -1.140556                          -1.137266       -1.136943
# ...                  ...                                ...             ...
# 2155           -1.140556                          -1.137266       -1.136943
# 2156           -1.140556                          -1.137266        0.879543
# 2157            0.876756                           0.879292        0.879543
# 2158            0.876756                           0.879292        0.879543
# 2159            0.876756                           0.879292        0.879543
#
#       total_cloud_cover:p_15  visibility:m_15  wind_speed_10m:ms_15  \
# 0                   0.879292         0.335965              0.320747
# 1                   0.879292         0.290122              0.282540
# 2                   0.879292         0.259565              0.244332
# 3                  -1.137266         0.221365              0.206125
# 4                  -1.137266         0.175523              0.175557
# ...                      ...              ...                   ...
# 2155               -1.137266        -1.337192             -1.329816
# 2156                0.879292        -1.298992             -1.299248
# 2157                0.879292        -1.276073             -1.268680
# 2158                0.879292        -1.245511             -1.245757
# 2159                0.879292        -1.222592             -1.222833
#
#       wind_speed_u_10m:ms_15  wind_speed_v_10m:ms_15  \
# 0                   0.313145                0.305495
# 1                   0.274934                0.267285
# 2                   0.236723                0.229076
# 3                   0.198513                0.190866
# 4                   0.167947                0.160297
# ...                      ...                     ...
# 2155               -1.322276               -1.314594
# 2156               -1.291710               -1.284024
# 2157               -1.261140               -1.253460
# 2158               -1.238214               -1.230530
# 2159               -1.215289               -1.207605
#
#       wind_speed_w_1000hPa:ms_15  absolute_humidity_2m:gm3_30  \
# 0                      -0.169307                    -0.167672
# 1                      -0.169307                    -0.167672
# 2                      -0.169307                    -0.167672
# 3                      -0.169307                    -0.167672
# 4                      -0.169307                    -0.167672
# ...                          ...                          ...
# 2155                   -0.169307                    -0.167672
# 2156                   -0.169307                    -0.167672
# 2157                   -0.169307                    -0.167672
# 2158                   -0.169307                    -0.167672
# 2159                   -0.169307                    -0.167672
#
#       air_density_2m:kgm3_30  ceiling_height_agl:m_30  \
# 0                  -0.172386                  -0.1732
# 1                  -0.172386                  -0.1732
# 2                  -0.172386                  -0.1732
# 3                  -0.172386                  -0.1732
# 4                  -0.172386                  -0.1732
# ...                      ...                      ...
# 2155               -0.172386                  -0.1732
# 2156               -0.172386                  -0.1732
# 2157               -0.172386                  -0.1732
# 2158               -0.172386                  -0.1732
# 2159               -0.172386                  -0.1732
#
#       clear_sky_energy_1h:J_30  clear_sky_rad:W_30  cloud_base_agl:m_30  \
# 0                    -0.216311           -0.217955             -0.21722
# 1                    -0.216311           -0.217955             -0.21722
# 2                    -0.216311           -0.217955             -0.21722
# 3                    -0.216311           -0.217955             -0.21722
# 4                    -0.216311           -0.217955             -0.21722
# ...                        ...                 ...                  ...
# 2155                 -0.216311           -0.217955             -0.21722
# 2156                 -0.216311           -0.217955             -0.21722
# 2157                 -0.216311           -0.217955             -0.21722
# 2158                 -0.216311           -0.217955             -0.21722
# 2159                 -0.216311           -0.217955             -0.21722
#
#       dew_or_rime:idx_30  dew_point_2m:K_30  diffuse_rad:W_30  \
# 0              -0.220466           0.375210          0.367623
# 1              -0.220466           0.336773          0.329178
# 2              -0.220466           0.298336          0.290733
# 3              -0.220466           0.259899          0.244602
# 4              -0.220466           0.221463          0.213844
# ...                  ...                ...               ...
# 2155           -0.220466          -1.415948         -1.408520
# 2156           -0.220466          -1.377511         -1.377762
# 2157           -0.220466          -1.362140         -1.354697
# 2158           -0.220466          -1.331389         -1.323944
# 2159           -0.220466          -1.308328         -1.300873
#
#       diffuse_rad_1h:J_30  direct_rad:W_30  direct_rad_1h:J_30  \
# 0                0.359979         0.352268            0.386484
# 1                0.321531         0.313822            0.348220
# 2                0.275396         0.267683            0.309956
# 3                0.236948         0.229237            0.264041
# 4                0.206188         0.198483            0.225777
# ...                   ...              ...                 ...
# 2155            -1.400933        -1.385508           -1.434882
# 2156            -1.370173        -1.362441           -1.396618
# 2157            -1.347105        -1.339370           -1.373661
# 2158            -1.316345        -1.308615           -1.343048
# 2159            -1.293277        -1.285548           -1.320090
#
#       effective_cloud_cover:p_30  elevation:m_30  fresh_snow_12h:cm_30  \
# 0                       0.378917        0.363644              0.355972
# 1                       0.340646        0.325370              0.317699
# 2                       0.302375        0.287095              0.279425
# 3                       0.256447        0.248821              0.233499
# 4                       0.218176        0.210547              0.202879
# ...                          ...             ...                   ...
# 2155                   -1.427480       -1.412290             -1.404602
# 2156                   -1.389209       -1.381668             -1.373982
# 2157                   -1.366247       -1.358704             -1.351019
# 2158                   -1.335628       -1.328088             -1.320398
# 2159                   -1.312666       -1.305119             -1.297435
#
#       fresh_snow_1h:cm_30  fresh_snow_24h:cm_30  fresh_snow_3h:cm_30  \
# 0               -0.139261             -0.138798            -0.139012
# 1               -0.139261             -0.138798            -0.139012
# 2               -0.139261             -0.138798            -0.139012
# 3               -0.139261             -0.138798            -0.139012
# 4               -0.139261             -0.138798            -0.139012
# ...                   ...                   ...                  ...
# 2155            -0.139261             -0.138798            -0.139012
# 2156            -0.139261             -0.138798            -0.139012
# 2157            -0.139261             -0.138798            -0.139012
# 2158            -0.139261             -0.138798            -0.139012
# 2159            -0.139261             -0.138798            -0.139012
#
#       fresh_snow_6h:cm_30  is_day:idx_30  is_in_shadow:idx_30  \
# 0               -0.138767       -0.22522            -0.226485
# 1               -0.138767       -0.22522            -0.226485
# 2               -0.138767       -0.22522            -0.226485
# 3               -0.138767       -0.22522            -0.226485
# 4               -0.138767       -0.22522            -0.226485
# ...                   ...            ...                  ...
# 2155            -0.138767       -0.22522            -0.226485
# 2156            -0.138767       -0.22522            -0.226485
# 2157            -0.138767       -0.22522            -0.226485
# 2158            -0.138767       -0.22522            -0.226485
# 2159            -0.138767       -0.22522            -0.226485
#
#       msl_pressure:hPa_30  precip_5min:mm_30  precip_type_5min:idx_30  \
# 0               -0.226715           -0.22718                 0.462743
# 1               -0.226715           -0.22718                 0.455764
# 2               -0.226715           -0.22718                 0.385973
# 3               -0.226715           -0.22718                 0.162643
# 4               -0.226715           -0.22718                 0.092852
# ...                   ...                ...                      ...
# 2155            -0.226715           -0.22718                -0.214227
# 2156            -0.226715           -0.22718                -0.018813
# 2157            -0.226715           -0.22718                 0.337120
# 2158            -0.226715           -0.22718                 0.693052
# 2159            -0.226715           -0.22718                 0.727948
#
#       pressure_100m:hPa_30  pressure_50m:hPa_30  prob_rime:p_30  \
# 0                 0.465273             0.466109        0.458202
# 1                 0.444219             0.423921        0.402053
# 2                 0.331932             0.276265        0.219569
# 3                 0.142447             0.128608        0.114290
# 4                 0.058232             0.023139       -0.019064
# ...                    ...                  ...             ...
# 2155             -0.166342            -0.117486       -0.068194
# 2156              0.072268             0.163764        0.247643
# 2157              0.430183             0.522359        0.605593
# 2158              0.703883             0.719235        0.724909
# 2159              0.753009             0.782516        0.802113
#
#       rain_water:kgm2_30  relative_humidity_1000hPa:p_30  sfc_pressure:hPa_30  \
# 0               0.395496                        0.387957             0.372760
# 1               0.357410                        0.349863             0.334664
# 2               0.319324                        0.304148             0.296567
# 3               0.273622                        0.266055             0.258471
# 4               0.235536                        0.227961             0.220375
# ...                  ...                             ...                  ...
# 2155           -1.447868                       -1.440532            -1.425385
# 2156           -1.409782                       -1.402439            -1.394911
# 2157           -1.386927                       -1.379584            -1.372054
# 2158           -1.348841                       -1.349107            -1.341575
# 2159           -1.325990                       -1.326252            -1.318718
#
#       snow_density:kgm3_30  snow_depth:cm_30  snow_drift:idx_30  \
# 0                 0.365135         -0.216887          -0.216288
# 1                 0.327040         -0.216887          -0.216288
# 2                 0.281322         -0.216887          -0.216288
# 3                 0.243227         -0.216887          -0.216288
# 4                 0.212753         -0.216887          -0.216288
# ...                    ...               ...                ...
# 2155             -1.417740         -0.216887          -0.216288
# 2156             -1.387262         -0.216887          -0.216288
# 2157             -1.356788         -0.216887          -0.216288
# 2158             -1.333932         -0.216887          -0.216288
# 2159             -1.311071         -0.216887          -0.216288
#
#       snow_melt_10min:mm_30  snow_water:kgm2_30  sun_azimuth:d_30  \
# 0                 -0.216506           -0.216696         -0.154033
# 1                 -0.216506           -0.216696         -0.154033
# 2                 -0.216506           -0.216696         -0.154033
# 3                 -0.216506           -0.216696         -0.154033
# 4                 -0.216506           -0.216696         -0.154033
# ...                     ...                 ...               ...
# 2155              -0.216506           -0.216696         -0.154033
# 2156              -0.216506           -0.216696         -0.154033
# 2157              -0.216506           -0.216696         -0.154033
# 2158              -0.216506           -0.216696         -0.154033
# 2159              -0.216506           -0.216696         -0.154033
#
#       sun_elevation:d_30  super_cooled_liquid_water:kgm2_30  t_1000hPa:K_30  \
# 0              -0.153997                          -0.154018       -0.154067
# 1              -0.153997                          -0.154018       -0.154067
# 2              -0.153997                          -0.154018       -0.154067
# 3              -0.153997                          -0.154018       -0.154067
# 4              -0.153997                          -0.154018       -0.154067
# ...                  ...                                ...             ...
# 2155           -0.153997                          -0.154018       -0.154067
# 2156           -0.153997                          -0.154018       -0.154067
# 2157           -0.153997                          -0.154018       -0.154067
# 2158           -0.153997                          -0.154018       -0.154067
# 2159           -0.153997                          -0.154018       -0.154067
#
#       total_cloud_cover:p_30  visibility:m_30  wind_speed_10m:ms_30  \
# 0                  -0.004639        -0.004639             -0.004639
# 1                  -0.004639        -0.004639             -0.004639
# 2                  -0.004639        -0.004639             -0.004639
# 3                  -0.004639        -0.004639             -0.004639
# 4                  -0.004639        -0.004639             -0.004639
# ...                      ...              ...                   ...
# 2155               -0.004639        -0.004639             -0.004639
# 2156               -0.004639        -0.004639             -0.004639
# 2157               -0.004639        -0.004639             -0.004639
# 2158               -0.004639        -0.004639             -0.004639
# 2159               -0.004639        -0.004639             -0.004639
#
#       wind_speed_u_10m:ms_30  wind_speed_v_10m:ms_30  \
# 0                  -0.004639               -0.063716
# 1                  -0.004639               -0.063716
# 2                  -0.004639               -0.063716
# 3                  -0.004639               -0.063716
# 4                  -0.004639               -0.063716
# ...                      ...                     ...
# 2155               -0.004639               -0.063716
# 2156               -0.004639               -0.063716
# 2157               -0.004639               -0.063716
# 2158               -0.004639               -0.063716
# 2159               -0.004639               -0.063716
#
#       wind_speed_w_1000hPa:ms_30  absolute_humidity_2m:gm3_45  \
# 0                      -0.063299                     -0.06382
# 1                      -0.063299                     -0.06382
# 2                      -0.063299                     -0.06382
# 3                      -0.063299                     -0.06382
# 4                      -0.063299                     -0.06382
# ...                          ...                          ...
# 2155                   -0.063299                     -0.06382
# 2156                   -0.063299                     -0.06382
# 2157                   -0.063299                     -0.06382
# 2158                   -0.063299                     -0.06382
# 2159                   -0.063299                     -0.06382
#
#       air_density_2m:kgm3_45  ceiling_height_agl:m_45  \
# 0                  -0.063921                -0.359869
# 1                  -0.063921                -0.359869
# 2                  -0.063921                -0.359869
# 3                  -0.063921                -0.359869
# 4                  -0.063921                -0.359869
# ...                      ...                      ...
# 2155               -0.063921                -0.359869
# 2156               -0.063921                -0.359869
# 2157               -0.063921                -0.359869
# 2158               -0.063921                -0.359869
# 2159               -0.063921                -0.359869
#
#       clear_sky_energy_1h:J_45  clear_sky_rad:W_45  cloud_base_agl:m_45  \
# 0                    -0.374748           -0.380472            -0.374735
# 1                    -0.374748           -0.380472            -0.374735
# 2                    -0.374748           -0.380472            -0.374735
# 3                    -0.374748           -0.380472            -0.374735
# 4                    -0.374748           -0.380472            -0.374735
# ...                        ...                 ...                  ...
# 2155                 -0.374748           -0.380472            -0.374735
# 2156                 -0.374748           -0.380472            -0.374735
# 2157                 -0.374748           -0.380472            -0.374735
# 2158                 -0.374748           -0.380472            -0.374735
# 2159                 -0.374748           -0.380472            -0.374735
#
#       dew_or_rime:idx_45  dew_point_2m:K_45  diffuse_rad:W_45  \
# 0              -1.670006          -1.617078         -1.540483
# 1              -1.527994          -1.476055         -1.400255
# 2              -1.390014          -1.339351         -1.264566
# 3              -1.256669          -1.207201         -1.133242
# 4              -1.127055          -1.078332         -1.004688
# ...                  ...                ...               ...
# 2155            1.160961           1.206795          1.282581
# 2156            1.286425           1.332751          1.409395
# 2157            1.414756           1.461795          1.539427
# 2158            1.546333           1.593984          1.672433
# 2159            1.680328           1.728222         -1.692308
#
#       diffuse_rad_1h:J_45  direct_rad:W_45  direct_rad_1h:J_45  \
# 0               -1.532527        -0.415545           -0.400570
# 1               -1.393297        -0.329874           -0.298154
# 2               -1.258697        -0.180689           -0.134681
# 3               -1.128201         0.021140            0.078313
# 4               -0.999884         0.262576            0.327542
# ...                   ...              ...                 ...
# 2155             1.287967         0.474358            0.415880
# 2156             1.415604         0.254704            0.206343
# 2157             1.546518         0.079906            0.044494
# 2158             1.680165        -0.039542           -0.059796
# 2159            -1.686169        -0.095809           -0.099404
#
#       effective_cloud_cover:p_45  elevation:m_45  fresh_snow_12h:cm_45  \
# 0                      -0.381240       -0.357719             -0.510793
# 1                      -0.262660       -0.223472             -0.510793
# 2                      -0.085603       -0.033618             -0.510793
# 3                       0.137728        0.199221             -0.510793
# 4                       0.393838        0.461383             -0.510793
# ...                          ...             ...                   ...
# 2155                    0.359643        0.305810              0.386216
# 2156                    0.160969        0.118747             -0.510793
# 2157                    0.012651       -0.015458             -0.510793
# 2158                   -0.075982       -0.088059             -0.510793
# 2159                   -0.098806       -0.093973              0.386216
#
#       fresh_snow_1h:cm_45  fresh_snow_24h:cm_45  fresh_snow_3h:cm_45  \
# 0               -0.527242             -0.532899            -0.527065
# 1               -0.527242             -0.532899            -0.527065
# 2               -0.527242             -0.532899            -0.527065
# 3               -0.527242             -0.532899            -0.527065
# 4               -0.527242             -0.532899            -0.527065
# ...                   ...                   ...                  ...
# 2155             0.397222              0.406303             0.399658
# 2156            -0.527242             -0.532899            -0.527065
# 2157            -0.527242             -0.532899            -0.527065
# 2158             0.397222              0.406303             0.399658
# 2159             0.397222              1.345504             1.326381
#
#       fresh_snow_6h:cm_45  is_day:idx_45  is_in_shadow:idx_45  \
# 0               -0.863611      -0.864088            -0.864175
# 1               -0.863611      -0.864088            -0.864175
# 2               -0.863611      -0.864088            -0.848826
# 3               -0.848274      -0.848742            -0.848826
# 4               -0.848274      -0.848742            -0.848826
# ...                   ...            ...                  ...
# 2155             1.160824       1.146184             1.131081
# 2156             1.099478       1.084803             1.069690
# 2157             1.022795       1.008075             0.992949
# 2158             0.946112       0.931347             0.916208
# 2159             0.884767       0.869966             0.870166
#
#       msl_pressure:hPa_45  precip_5min:mm_45  precip_type_5min:idx_45  \
# 0               -0.863963           0.202776                 0.096072
# 1               -0.863963          -0.260173                 0.011326
# 2               -0.848617           0.594282                 0.496423
# 3               -0.848617           0.039886                -0.090954
# 4               -0.833271          -0.428778                -0.292590
# ...                   ...                ...                      ...
# 2155             1.115549           0.477116                 0.440900
# 2156             1.054165           0.325657                 0.207118
# 2157             0.977440          -0.105857                 0.081460
# 2158             0.900715           0.754314                 0.768194
# 2159             0.854682           0.754314                 0.768194
#
#       pressure_100m:hPa_45  pressure_50m:hPa_45  prob_rime:p_45  \
# 0                -0.019031            -0.137582       -0.153787
# 1                 0.251861             0.446980       -0.192173
# 2                 0.369640             0.213155       -0.194596
# 3                -0.216310            -0.330487        0.038166
# 4                -0.142698             0.008559        0.158286
# ...                    ...                  ...             ...
# 2155              0.402029             0.365141        0.464457
# 2156              0.089915            -0.014824        0.388040
# 2157              0.296028             0.522973        0.558878
# 2158              0.773033             0.768489        0.326978
# 2159              0.773033             0.768489        0.327420
#
#       rain_water:kgm2_45  relative_humidity_1000hPa:p_45  sfc_pressure:hPa_45  \
# 0              -0.167967                       -0.180413            -0.189080
# 1              -0.194356                       -0.195317            -0.195136
# 2              -0.142184                       -0.084636            -0.023673
# 3               0.070657                        0.100584             0.130021
# 4               0.144852                        0.129459             0.111868
# ...                  ...                             ...                  ...
# 2155            0.453209                        0.436429             0.414533
# 2156            0.438972                        0.485620             0.526126
# 2157            0.510343                        0.452898             0.391168
# 2158            0.332143                        0.334111             0.332644
# 2159            0.336461                        0.342189             0.344273
#
#       snow_density:kgm3_45  snow_depth:cm_45  snow_drift:idx_45  \
# 0                 0.540953          0.545231           0.489882
# 1                 0.484727          0.431868           0.433034
# 2                 0.372273          0.375186           0.319337
# 3                 0.316045          0.261823           0.262489
# 4                 0.203592          0.148459           0.148792
# ...                    ...               ...                ...
# 2155             -0.471132         -0.475039          -0.476538
# 2156             -0.527359         -0.475039          -0.476538
# 2157             -0.358678         -0.418357          -0.476538
# 2158             -0.583586         -0.645084          -0.703932
# 2159             -0.752267         -0.758448          -0.760780
#
#       snow_melt_10min:mm_45  snow_water:kgm2_45  sun_azimuth:d_45  \
# 0                  0.488419            0.547326          0.511469
# 1                  0.431731            0.476126          0.440207
# 2                  0.318354            0.404926          0.404576
# 3                  0.204978            0.333726          0.297683
# 4                  0.148290            0.226926          0.226421
# ...                     ...                 ...               ...
# 2155              -0.531967            0.440526          0.440207
# 2156              -0.418591            0.440526          0.475838
# 2157              -0.531967            0.547326          0.511469
# 2158              -0.702031            0.404926          0.368945
# 2159              -0.758719            0.333726          0.333314
#
#       sun_elevation:d_45  super_cooled_liquid_water:kgm2_45  t_1000hPa:K_45  \
# 0               0.511151                           0.475527        1.432581
# 1               0.439871                           0.439898        1.379866
# 2               0.368590                           0.368640        1.327151
# 3               0.261668                           0.226123        1.327151
# 4               0.226028                           0.226123        1.274436
# ...                  ...                                ...             ...
# 2155            0.439871                           0.439898       -0.992306
# 2156            0.475511                           0.511156       -0.834161
# 2157            0.475511                           0.439898       -0.886876
# 2158            0.368590                           0.333011       -0.781446
# 2159            0.332949                           0.333011       -0.728732
#
#       total_cloud_cover:p_45  visibility:m_45  wind_speed_10m:ms_45  \
# 0                   1.439571         1.389115                   0.0
# 1                   1.386532         1.389115                   0.0
# 2                   1.333493         1.335956                   0.0
# 3                   1.333493         1.282798                   0.0
# 4                   1.280454         1.229639                   0.0
# ...                      ...              ...                   ...
# 2155               -0.947187        -0.896704                   0.0
# 2156               -0.841109        -0.843545                   0.0
# 2157               -0.894148        -0.843545                   0.0
# 2158               -0.788070        -0.790387                   0.0
# 2159               -0.681992        -0.684069                   0.0
#
#       wind_speed_u_10m:ms_45  wind_speed_v_10m:ms_45  \
# 0                   0.002482                0.002208
# 1                   0.002482                0.002208
# 2                   0.002482                0.002208
# 3                   0.002482                0.002208
# 4                   0.002482                0.002208
# ...                      ...                     ...
# 2155                0.002482                0.002208
# 2156                0.002482                0.002208
# 2157                0.002482                0.002208
# 2158                0.002482                0.002208
# 2159                0.002482                0.002208
#
#       wind_speed_w_1000hPa:ms_45  day  hour
# 0                       0.000171    0     0
# 1                       0.000171    0     1
# 2                       0.000171    0     2
# 3                       0.000171    0     3
# 4                       0.000171    0     4
# ...                          ...  ...   ...
# 2155                    0.000171    0    19
# 2156                    0.000171    0    20
# 2157                    0.000171    0    21
# 2158                    0.000171    0    22
# 2159                    0.000171    0    23
#
# [2160 rows x 183 columns]

# %%
#!ReWrite
def models_predict(models, X):
    preds = X.iloc[:,1:2]

    for i in range(len(models)):
        preds[str(i)] = models[i].predict(X)

    preds = preds.iloc[:,1:]
    preds["final"] = preds.mean(axis=1)
    return preds["final"]

# %%
test_preds = pd.read_csv("sample_submission.csv")
test_preds["prediction"] = models_predict(models, X_test)
display(test_preds)
test_preds.to_csv("preds/Ensamble2_withoutlocationInput.csv", index=False)
# Out:
# 68/68 [==============================] - 0s 4ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 3ms/step
# 68/68 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 2ms/step
#         id  prediction
# 0        0    0.000000
# 1        1    0.000000
# 2        2    0.000000
# 3        3   54.583904
# 4        4  389.394775
# ...    ...         ...
# 2155  2155   58.412697
# 2156  2156   26.179794
# 2157  2157    1.342794
# 2158  2158    0.408505
# 2159  2159    0.182203
#
# [2160 rows x 2 columns]
